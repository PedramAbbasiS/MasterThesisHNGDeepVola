# %% [markdown]
# # Summary
# This code gives a short summary on the current progress (last update: 17.12.19).
# In the following a CNN aswell as a FFNN are trained to learn the mapping HNG-Parameters (w,a,b,g*,h0) to HNG-Volatility surface. A first approach on  training the inverse mapping with CNN is given.

# %% [markdown]
# # 1. Preambel and Data Import

# %%
# Preambel
import numpy as np
from sklearn.model_selection import train_test_split
#from sklearn.preprocessing import StandardScaler
import keras
from keras.models import Sequential,Model
from keras.layers import InputLayer,Dense,Flatten, Conv2D, Dropout, Input,ZeroPadding2D,MaxPooling2D
from keras import backend as K
import matplotlib.pyplot as plt
import matplotlib.ticker as mtick
#import py_vollib.black_scholes.implied_volatility as vol
#import time
import scipy
import scipy.io

# scaler
def ytransform(y_train,y_val,y_test):
    #return [scale.transform(y_train),scale.transform(y_val), 
    #        scale.transform(y_test)]
    return [y_train,y_val,y_test]

def yinversetransform(y):
    return y
    #return scale.inverse_transform(y)
    
def myscale(x):
    res=np.zeros(Nparameters)
    for i in range(Nparameters):
        res[i]=(x[i] - (ub[i] + lb[i])*0.5) * 2 / (ub[i] + lb[i])
    return res

def myinverse(x):
    res=np.zeros(Nparameters)
    for i in range(Nparameters):
        res[i]=x[i]*(ub[i] + lb[i]) *0.5 + (ub[i] + lb[i])*0.5
    return res

def root_mean_squared_error(y_true, y_pred):
        return K.sqrt(K.mean(K.square(y_pred - y_true)))   
def root_relative_mean_squared_error(y_true, y_pred):
        return K.sqrt(K.mean(K.square((y_pred - y_true)/y_true)))    
    
# Data Import
mat         = scipy.io.loadmat('data_vola_maxbounds_50000_0005_09_11_30_210.mat')
data        = mat['data_vola']
Nparameters = 5
maturities  = np.array([30, 60, 90, 120, 150, 180, 210])
strikes     = np.array([0.9, 0.925, 0.95, 0.975, 1.0, 1.025, 1.05, 1.075, 1.1])
Nstrikes    = len(strikes)   
Nmaturities = len(maturities)   
xx          = data[:,:Nparameters]
yy          = data[:,Nparameters+2:]

ub=np.amax(xx, axis=0)
lb=np.amin(xx, axis=0)

# split into train and test sample
X_train, X_test, y_train, y_test = train_test_split(
    xx, yy, test_size=0.15)#, random_state=42)

X_train, X_val, y_train, y_val = train_test_split(
   X_train, y_train, test_size=0.15)#, random_state=42)

Ntest= X_test.shape[0]
Ntrain= X_train.shape[0]
Nval= X_val.shape[0]
keras.backend.set_floatx('float64')
# Out:
# Using TensorFlow backend.

# %% [markdown]
# # 2. CNN as Encoder

# %%
# reshaping train/test sets for structure purposes
[y_train_trafo, y_val_trafo, y_test_trafo]=ytransform(y_train, y_val, y_test)
y_train_trafo = np.asarray([y_train[i,:].reshape((1,Nmaturities,Nstrikes)) for i in range(Ntrain)])
y_val_trafo =  np.asarray([y_val[i,:].reshape((1,Nmaturities,Nstrikes)) for i in range(Nval)])
y_test_trafo =  np.asarray([y_test[i,:].reshape((1,Nmaturities,Nstrikes)) for i in range(Ntest)])

X_train_trafo = np.array([myscale(x) for x in X_train])
X_val_trafo   = np.array([myscale(x) for x in X_val])
X_test_trafo  = np.array([myscale(x) for x in X_test])
X_train_trafo = np.array([myscale(x) for x in X_train])
X_val_trafo   = np.array([myscale(x) for x in X_val])
X_test_trafo  = X_test_trafo.reshape((Ntest,5,1,1))
X_train_trafo = X_train_trafo.reshape((Ntrain,5,1,1))
X_val_trafo   = X_val_trafo.reshape((Nval,5,1,1))

NN1 = Sequential() 
NN1.add(InputLayer(input_shape=(Nparameters,1,1,)))
NN1.add(ZeroPadding2D(padding=(2, 2)))
NN1.add(Conv2D(32, (3, 1), padding='valid',strides =(1,1),activation='elu'))#X_train_trafo.shape[1:],activation='elu'))
NN1.add(ZeroPadding2D(padding=(1,1)))
NN1.add(Conv2D(32, (2, 2),padding='valid',strides =(1,1),activation ='elu'))
NN1.add(Conv2D(32, (2, 2),padding='valid',strides =(2,1),activation ='elu'))
NN1.add(ZeroPadding2D(padding=(1,1)))
NN1.add(Conv2D(32, (3,3),padding='valid',strides =(2,1),activation ='elu'))
NN1.add(ZeroPadding2D(padding=(1,1)))
NN1.add(Conv2D(32, (2, 2),padding='valid',strides =(2,1),activation ='elu'))
NN1.add(ZeroPadding2D(padding=(1,1)))
NN1.add(Conv2D(32, (2, 2),padding='valid',strides =(2,1),activation ='elu'))
#NN1.add(MaxPooling2D(pool_size=(2, 1)))
#NN1.add(Dropout(0.25))
#NN1.add(ZeroPadding2D(padding=(0,1)))
NN1.add(Conv2D(Nstrikes, (2, 1),padding='valid',strides =(2,1),activation ='linear', kernel_constraint = keras.constraints.NonNeg()))
#NN1.add(MaxPooling2D(pool_size=(4, 1)))
NN1.summary()
NN1.compile(loss = root_relative_mean_squared_error, optimizer = "adam",metrics=["MAPE","MSE"])
NN1.fit(X_train_trafo, y_train_trafo, batch_size=64, validation_data = (X_val_trafo, y_val_trafo),
        epochs = 50, verbose = True, shuffle=1)
# Out:
# WARNING:tensorflow:From D:\Programme\Anaconda\lib\site-packages\keras\backend\tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From D:\Programme\Anaconda\lib\site-packages\keras\backend\tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From D:\Programme\Anaconda\lib\site-packages\keras\backend\tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# zero_padding2d_1 (ZeroPaddin (None, 9, 5, 1)           0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 7, 5, 32)          128
# _________________________________________________________________
# zero_padding2d_2 (ZeroPaddin (None, 9, 7, 32)          0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 8, 6, 32)          4128
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 4, 5, 32)          4128
# _________________________________________________________________
# zero_padding2d_3 (ZeroPaddin (None, 6, 7, 32)          0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 2, 5, 32)          9248
# _________________________________________________________________
# zero_padding2d_4 (ZeroPaddin (None, 4, 7, 32)          0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 2, 6, 32)          4128
# _________________________________________________________________
# zero_padding2d_5 (ZeroPaddin (None, 4, 8, 32)          0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 2, 7, 32)          4128
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 1, 7, 9)           585
# =================================================================
# Total params: 26,473
# Trainable params: 26,473
# Non-trainable params: 0
# _________________________________________________________________
# WARNING:tensorflow:From D:\Programme\Anaconda\lib\site-packages\keras\optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# WARNING:tensorflow:From D:\Programme\Anaconda\lib\site-packages\tensorflow\python\ops\math_grad.py:1250: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From D:\Programme\Anaconda\lib\site-packages\keras\backend\tensorflow_backend.py:986: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# WARNING:tensorflow:From D:\Programme\Anaconda\lib\site-packages\keras\backend\tensorflow_backend.py:973: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# Train on 36085 samples, validate on 6369 samples
# Epoch 1/50
# 36085/36085 [==============================] - 12s 322us/step - loss: 0.2374 - mean_absolute_percentage_error: 17.9216 - mean_squared_error: 0.0043 - val_loss: 0.1982 - val_mean_absolute_percentage_error: 14.4738 - val_mean_squared_error: 0.0038
# Epoch 2/50
# 36085/36085 [==============================] - 10s 287us/step - loss: 0.1926 - mean_absolute_percentage_error: 13.9767 - mean_squared_error: 0.0035 - val_loss: 0.1831 - val_mean_absolute_percentage_error: 13.3341 - val_mean_squared_error: 0.0035
# Epoch 3/50
# 36085/36085 [==============================] - 11s 293us/step - loss: 0.1708 - mean_absolute_percentage_error: 12.0986 - mean_squared_error: 0.0030 - val_loss: 0.1594 - val_mean_absolute_percentage_error: 11.1178 - val_mean_squared_error: 0.0030
# Epoch 4/50
# 36085/36085 [==============================] - 10s 279us/step - loss: 0.1480 - mean_absolute_percentage_error: 10.1667 - mean_squared_error: 0.0025 - val_loss: 0.1376 - val_mean_absolute_percentage_error: 9.3390 - val_mean_squared_error: 0.0023
# Epoch 5/50
# 36085/36085 [==============================] - 10s 273us/step - loss: 0.1244 - mean_absolute_percentage_error: 8.3824 - mean_squared_error: 0.0019 - val_loss: 0.1270 - val_mean_absolute_percentage_error: 8.5221 - val_mean_squared_error: 0.0018
# Epoch 6/50
# 36085/36085 [==============================] - 10s 269us/step - loss: 0.1029 - mean_absolute_percentage_error: 6.7801 - mean_squared_error: 0.0014 - val_loss: 0.0888 - val_mean_absolute_percentage_error: 5.5359 - val_mean_squared_error: 0.0013
# Epoch 7/50
# 36085/36085 [==============================] - 10s 268us/step - loss: 0.0865 - mean_absolute_percentage_error: 5.6285 - mean_squared_error: 0.0011 - val_loss: 0.0908 - val_mean_absolute_percentage_error: 6.2977 - val_mean_squared_error: 0.0010
# Epoch 8/50
# 36085/36085 [==============================] - 10s 272us/step - loss: 0.0774 - mean_absolute_percentage_error: 5.0359 - mean_squared_error: 8.2969e-04 - val_loss: 0.0700 - val_mean_absolute_percentage_error: 4.4326 - val_mean_squared_error: 8.8458e-04
# Epoch 9/50
# 36085/36085 [==============================] - 10s 270us/step - loss: 0.0686 - mean_absolute_percentage_error: 4.4464 - mean_squared_error: 6.6303e-04 - val_loss: 0.0684 - val_mean_absolute_percentage_error: 4.4741 - val_mean_squared_error: 7.0946e-04
# Epoch 10/50
# 36085/36085 [==============================] - 10s 269us/step - loss: 0.0645 - mean_absolute_percentage_error: 4.2613 - mean_squared_error: 5.6649e-04 - val_loss: 0.0579 - val_mean_absolute_percentage_error: 3.8980 - val_mean_squared_error: 5.0663e-04
# Epoch 11/50
# 36085/36085 [==============================] - 11s 303us/step - loss: 0.0598 - mean_absolute_percentage_error: 3.9261 - mean_squared_error: 4.8132e-04 - val_loss: 0.0629 - val_mean_absolute_percentage_error: 4.3744 - val_mean_squared_error: 6.6517e-04
# Epoch 12/50
# 36085/36085 [==============================] - 10s 270us/step - loss: 0.0561 - mean_absolute_percentage_error: 3.6901 - mean_squared_error: 4.2581e-04 - val_loss: 0.0503 - val_mean_absolute_percentage_error: 3.4437 - val_mean_squared_error: 4.0805e-04
# Epoch 13/50
# 36085/36085 [==============================] - 12s 324us/step - loss: 0.0510 - mean_absolute_percentage_error: 3.3426 - mean_squared_error: 3.6456e-04 - val_loss: 0.0568 - val_mean_absolute_percentage_error: 3.5695 - val_mean_squared_error: 3.8347e-04
# Epoch 14/50
# 36085/36085 [==============================] - 13s 348us/step - loss: 0.0503 - mean_absolute_percentage_error: 3.3219 - mean_squared_error: 3.3388e-04 - val_loss: 0.0459 - val_mean_absolute_percentage_error: 2.8639 - val_mean_squared_error: 3.3883e-04
# Epoch 15/50
# 36085/36085 [==============================] - 10s 265us/step - loss: 0.0479 - mean_absolute_percentage_error: 3.1576 - mean_squared_error: 3.1285e-04 - val_loss: 0.0385 - val_mean_absolute_percentage_error: 2.3179 - val_mean_squared_error: 3.3111e-04rcentage_error: 3.1695 - mean_square
# Epoch 16/50
# 36085/36085 [==============================] - 9s 256us/step - loss: 0.0457 - mean_absolute_percentage_error: 3.0172 - mean_squared_error: 2.8676e-04 - val_loss: 0.0501 - val_mean_absolute_percentage_error: 2.8665 - val_mean_squared_error: 2.9967e-04
# Epoch 17/50
# 36085/36085 [==============================] - 10s 280us/step - loss: 0.0468 - mean_absolute_percentage_error: 3.1334 - mean_squared_error: 2.7593e-04 - val_loss: 0.0412 - val_mean_absolute_percentage_error: 2.8017 - val_mean_squared_error: 2.6449e-04
# Epoch 18/50
# 36085/36085 [==============================] - 10s 286us/step - loss: 0.0436 - mean_absolute_percentage_error: 2.9217 - mean_squared_error: 2.5014e-04 - val_loss: 0.0429 - val_mean_absolute_percentage_error: 3.1514 - val_mean_squared_error: 2.6223e-04
# Epoch 19/50
# 36085/36085 [==============================] - 10s 267us/step - loss: 0.0441 - mean_absolute_percentage_error: 2.9356 - mean_squared_error: 2.4643e-04 - val_loss: 0.0462 - val_mean_absolute_percentage_error: 3.2576 - val_mean_squared_error: 2.9892e-04
# Epoch 20/50
# 36085/36085 [==============================] - 10s 268us/step - loss: 0.0419 - mean_absolute_percentage_error: 2.7734 - mean_squared_error: 2.3193e-04 - val_loss: 0.0481 - val_mean_absolute_percentage_error: 3.1133 - val_mean_squared_error: 3.3316e-04
# Epoch 21/50
# 36085/36085 [==============================] - 10s 267us/step - loss: 0.0418 - mean_absolute_percentage_error: 2.7905 - mean_squared_error: 2.1752e-04 - val_loss: 0.0674 - val_mean_absolute_percentage_error: 5.6849 - val_mean_squared_error: 3.1717e-04
# Epoch 22/50
# 36085/36085 [==============================] - 10s 268us/step - loss: 0.0410 - mean_absolute_percentage_error: 2.7394 - mean_squared_error: 2.1057e-04 - val_loss: 0.0374 - val_mean_absolute_percentage_error: 2.3639 - val_mean_squared_error: 1.9121e-045 - mean_absolute_percentage_error: 2.7657 - mean_squared_erro - ETA: 4s - loss:
# Epoch 23/50
# 36085/36085 [==============================] - 11s 311us/step - loss: 0.0394 - mean_absolute_percentage_error: 2.6040 - mean_squared_error: 2.0363e-04 - val_loss: 0.0303 - val_mean_absolute_percentage_error: 1.8222 - val_mean_squared_error: 2.1189e-04
# Epoch 24/50
# 36085/36085 [==============================] - 10s 283us/step - loss: 0.0406 - mean_absolute_percentage_error: 2.7034 - mean_squared_error: 2.0316e-04 - val_loss: 0.0421 - val_mean_absolute_percentage_error: 2.8465 - val_mean_squared_error: 2.4477e-04
# Epoch 25/50
# 36085/36085 [==============================] - 10s 282us/step - loss: 0.0400 - mean_absolute_percentage_error: 2.6345 - mean_squared_error: 1.9899e-04 - val_loss: 0.0571 - val_mean_absolute_percentage_error: 3.7592 - val_mean_squared_error: 2.4218e-04
# Epoch 26/50
# 36085/36085 [==============================] - 10s 269us/step - loss: 0.0375 - mean_absolute_percentage_error: 2.5080 - mean_squared_error: 1.8386e-04 - val_loss: 0.0331 - val_mean_absolute_percentage_error: 2.2220 - val_mean_squared_error: 2.1252e-04
# Epoch 27/50
# 36085/36085 [==============================] - 10s 267us/step - loss: 0.0386 - mean_absolute_percentage_error: 2.5494 - mean_squared_error: 1.8991e-04 - val_loss: 0.0340 - val_mean_absolute_percentage_error: 2.3551 - val_mean_squared_error: 1.5318e-04
# Epoch 28/50
# 36085/36085 [==============================] - 10s 267us/step - loss: 0.0380 - mean_absolute_percentage_error: 2.5164 - mean_squared_error: 1.8283e-04 - val_loss: 0.0363 - val_mean_absolute_percentage_error: 2.2651 - val_mean_squared_error: 1.5796e-04
# Epoch 29/50
# 36085/36085 [==============================] - 10s 272us/step - loss: 0.0374 - mean_absolute_percentage_error: 2.4831 - mean_squared_error: 1.7963e-04 - val_loss: 0.0262 - val_mean_absolute_percentage_error: 1.5144 - val_mean_squared_error: 1.8844e-04
# Epoch 30/50
# 36085/36085 [==============================] - 10s 267us/step - loss: 0.0358 - mean_absolute_percentage_error: 2.3651 - mean_squared_error: 1.6738e-04 - val_loss: 0.0397 - val_mean_absolute_percentage_error: 2.6431 - val_mean_squared_error: 1.5724e-04
# Epoch 31/50
# 36085/36085 [==============================] - 10s 267us/step - loss: 0.0344 - mean_absolute_percentage_error: 2.2453 - mean_squared_error: 1.5741e-04 - val_loss: 0.0380 - val_mean_absolute_percentage_error: 2.3719 - val_mean_squared_error: 1.5190e-04
# Epoch 32/50
# 36085/36085 [==============================] - 10s 267us/step - loss: 0.0373 - mean_absolute_percentage_error: 2.4814 - mean_squared_error: 1.8061e-04 - val_loss: 0.0424 - val_mean_absolute_percentage_error: 2.3791 - val_mean_squared_error: 1.4350e-04ute_perce
# Epoch 33/50
# 36085/36085 [==============================] - 10s 267us/step - loss: 0.0348 - mean_absolute_percentage_error: 2.3127 - mean_squared_error: 1.5132e-04 - val_loss: 0.0475 - val_mean_absolute_percentage_error: 3.0721 - val_mean_squared_error: 3.8165e-04
# Epoch 34/50
# 36085/36085 [==============================] - 10s 268us/step - loss: 0.0350 - mean_absolute_percentage_error: 2.3364 - mean_squared_error: 1.5657e-04 - val_loss: 0.0366 - val_mean_absolute_percentage_error: 2.6595 - val_mean_squared_error: 1.3494e-04
# Epoch 35/50
# 36085/36085 [==============================] - 11s 304us/step - loss: 0.0338 - mean_absolute_percentage_error: 2.2282 - mean_squared_error: 1.5239e-04 - val_loss: 0.0352 - val_mean_absolute_percentage_error: 2.4113 - val_mean_squared_error: 1.4144e-04
# Epoch 36/50
# 36085/36085 [==============================] - 10s 269us/step - loss: 0.0335 - mean_absolute_percentage_error: 2.2304 - mean_squared_error: 1.5245e-04 - val_loss: 0.0263 - val_mean_absolute_percentage_error: 1.6388 - val_mean_squared_error: 1.4820e-04
# Epoch 37/50
# 36085/36085 [==============================] - 10s 268us/step - loss: 0.0353 - mean_absolute_percentage_error: 2.3531 - mean_squared_error: 1.5413e-04 - val_loss: 0.0382 - val_mean_absolute_percentage_error: 2.2855 - val_mean_squared_error: 2.7733e-04
# Epoch 38/50
# 36085/36085 [==============================] - 10s 268us/step - loss: 0.0332 - mean_absolute_percentage_error: 2.1970 - mean_squared_error: 1.5100e-04 - val_loss: 0.0413 - val_mean_absolute_percentage_error: 2.8459 - val_mean_squared_error: 1.7198e-04
# Epoch 39/50
# 36085/36085 [==============================] - 10s 269us/step - loss: 0.0346 - mean_absolute_percentage_error: 2.2779 - mean_squared_error: 1.4914e-04 - val_loss: 0.0348 - val_mean_absolute_percentage_error: 2.5170 - val_mean_squared_error: 1.5174e-04
# Epoch 40/50
# 36085/36085 [==============================] - 10s 270us/step - loss: 0.0338 - mean_absolute_percentage_error: 2.2677 - mean_squared_error: 1.3741e-04 - val_loss: 0.0299 - val_mean_absolute_percentage_error: 1.6005 - val_mean_squared_error: 1.1607e-04
# Epoch 41/50
# 36085/36085 [==============================] - 10s 277us/step - loss: 0.0333 - mean_absolute_percentage_error: 2.1799 - mean_squared_error: 1.4657e-04 - val_loss: 0.0263 - val_mean_absolute_percentage_error: 1.7431 - val_mean_squared_error: 1.3047e-04
# Epoch 42/50
# 36085/36085 [==============================] - 10s 272us/step - loss: 0.0321 - mean_absolute_percentage_error: 2.1171 - mean_squared_error: 1.3159e-04 - val_loss: 0.0367 - val_mean_absolute_percentage_error: 2.2231 - val_mean_squared_error: 1.5484e-04
# Epoch 43/50
# 36085/36085 [==============================] - 10s 268us/step - loss: 0.0314 - mean_absolute_percentage_error: 2.0650 - mean_squared_error: 1.2778e-04 - val_loss: 0.0308 - val_mean_absolute_percentage_error: 1.7901 - val_mean_squared_error: 1.3044e-04
# Epoch 44/50
# 36085/36085 [==============================] - 10s 276us/step - loss: 0.0328 - mean_absolute_percentage_error: 2.1524 - mean_squared_error: 1.4257e-04 - val_loss: 0.0320 - val_mean_absolute_percentage_error: 1.9035 - val_mean_squared_error: 1.2290e-04
# Epoch 45/50
# 36085/36085 [==============================] - 10s 268us/step - loss: 0.0320 - mean_absolute_percentage_error: 2.1004 - mean_squared_error: 1.4210e-04 - val_loss: 0.0382 - val_mean_absolute_percentage_error: 3.1807 - val_mean_squared_error: 1.3437e-04
# Epoch 46/50
# 36085/36085 [==============================] - 10s 274us/step - loss: 0.0298 - mean_absolute_percentage_error: 1.9732 - mean_squared_error: 1.2472e-04 - val_loss: 0.0309 - val_mean_absolute_percentage_error: 2.0548 - val_mean_squared_error: 1.5890e-04
# Epoch 47/50
# 36085/36085 [==============================] - 11s 300us/step - loss: 0.0304 - mean_absolute_percentage_error: 2.0031 - mean_squared_error: 1.2639e-04 - val_loss: 0.0313 - val_mean_absolute_percentage_error: 2.1344 - val_mean_squared_error: 1.1317e-04
# Epoch 48/50
# 36085/36085 [==============================] - 10s 276us/step - loss: 0.0312 - mean_absolute_percentage_error: 2.0773 - mean_squared_error: 1.2381e-04 - val_loss: 0.0323 - val_mean_absolute_percentage_error: 2.2364 - val_mean_squared_error: 1.2990e-04
# Epoch 49/50
# 36085/36085 [==============================] - 10s 273us/step - loss: 0.0322 - mean_absolute_percentage_error: 2.1534 - mean_squared_error: 1.2461e-04 - val_loss: 0.0310 - val_mean_absolute_percentage_error: 1.9497 - val_mean_squared_error: 1.4631e-04
# Epoch 50/50
# 36085/36085 [==============================] - 10s 272us/step - loss: 0.0307 - mean_absolute_percentage_error: 2.0435 - mean_squared_error: 1.1701e-04 - val_loss: 0.0302 - val_mean_absolute_percentage_error: 1.9566 - val_mean_squared_error: 1.9231e-04

# %% [markdown]
# ### 2.1 Results
# The following plots show the performance on the testing set

# %%
#error plots
S0=1.
y_test_re    = yinversetransform(y_test_trafo).reshape((Ntest,Nmaturities,Nstrikes))
prediction   = NN1.predict(X_test_trafo).reshape((Ntest,Nmaturities,Nstrikes))
err_rel_mat  = np.zeros(prediction.shape)
err_mat      = np.zeros(prediction.shape)
for i in range(Ntest):
    err_rel_mat[i,:,:] =  np.abs((y_test_re[i,:,:]-prediction[i,:,:])/y_test_re[i,:,:])
    err_mat[i,:,:] =  np.square((y_test_re[i,:,:]-prediction[i,:,:]))
idx = np.argsort(np.max(err_rel_mat,axis=tuple([1,2])), axis=None)

#bad_idx = idx[:-200]
bad_idx = idx
#from matplotlib.colors import LogNorm
plt.figure(figsize=(14,4))
ax=plt.subplot(2,3,1)
err1 = 100*np.mean(err_rel_mat[bad_idx,:,:],axis=0)
plt.title("Average relative error",fontsize=15,y=1.04)
plt.imshow(err1)#,norm=LogNorm(vmin=err1.min(), vmax=err1.max()))
plt.setp(ax.get_xticklabels(), rotation=30, horizontalalignment='right')
plt.colorbar(format=mtick.PercentFormatter())
ax.set_xticks(np.linspace(0,Nstrikes-1,Nstrikes))
ax.set_xticklabels(strikes)
ax.set_yticks(np.linspace(0,Nmaturities-1,Nmaturities))
ax.set_yticklabels(maturities)
plt.xlabel("Strike",fontsize=15,labelpad=5)
plt.ylabel("Maturity",fontsize=15,labelpad=5)
ax=plt.subplot(2,3,2)
err2 = 100*np.std(err_rel_mat[bad_idx,:,:],axis = 0)
plt.title("Std relative error",fontsize=15,y=1.04)
plt.imshow(err2)#,norm=LogNorm(vmin=err2.min(), vmax=err2.max()))
plt.colorbar(format=mtick.PercentFormatter())
plt.setp(ax.get_xticklabels(), rotation=30, horizontalalignment='right')
ax.set_xticks(np.linspace(0,Nstrikes-1,Nstrikes))
ax.set_xticklabels(strikes)
ax.set_yticks(np.linspace(0,Nmaturities-1,Nmaturities))
ax.set_yticklabels(maturities)
plt.xlabel("Strike",fontsize=15,labelpad=5)
plt.ylabel("Maturity",fontsize=15,labelpad=5)
ax=plt.subplot(2,3,3)
err3 = 100*np.max(err_rel_mat[bad_idx,:,:],axis = 0)
plt.title("Maximum relative error",fontsize=15,y=1.04)
plt.imshow(err3)#,norm=LogNorm(vmin=err3.min(), vmax=err3.max()))
plt.colorbar(format=mtick.PercentFormatter())
plt.setp(ax.get_xticklabels(), rotation=30, horizontalalignment='right')
ax.set_xticks(np.linspace(0,Nstrikes-1,Nstrikes))
ax.set_xticklabels(strikes)
ax.set_yticks(np.linspace(0,Nmaturities-1,Nmaturities))
ax.set_yticklabels(maturities)
plt.xlabel("Strike",fontsize=15,labelpad=5)
plt.ylabel("Maturity",fontsize=15,labelpad=5)
ax=plt.subplot(2,3,4)
err1 = np.sqrt(np.mean(err_mat[bad_idx,:,:],axis=0))
plt.title("RMSE",fontsize=15,y=1.04)
plt.imshow(err1)#,norm=LogNorm(vmin=err1.min(), vmax=err1.max()))
plt.colorbar(format=mtick.PercentFormatter())
plt.setp(ax.get_xticklabels(), rotation=30, horizontalalignment='right')
ax.set_xticks(np.linspace(0,Nstrikes-1,Nstrikes))
ax.set_xticklabels(strikes)
ax.set_yticks(np.linspace(0,Nmaturities-1,Nmaturities))
ax.set_yticklabels(maturities)
plt.xlabel("Strike",fontsize=15,labelpad=5)
plt.ylabel("Maturity",fontsize=15,labelpad=5)
ax=plt.subplot(2,3,5)
err2 = np.std(err_mat[bad_idx,:,:],axis = 0)
plt.title("Std MSE",fontsize=15,y=1.04)
plt.imshow(err2)#,norm=LogNorm(vmin=err2.min(), vmax=err2.max()))
plt.colorbar(format=mtick.PercentFormatter())
plt.setp(ax.get_xticklabels(), rotation=30, horizontalalignment='right')
ax.set_xticks(np.linspace(0,Nstrikes-1,Nstrikes))
ax.set_xticklabels(strikes)
ax.set_yticks(np.linspace(0,Nmaturities-1,Nmaturities))
ax.set_yticklabels(maturities)
plt.xlabel("Strike",fontsize=15,labelpad=5)
plt.ylabel("Maturity",fontsize=15,labelpad=5)
ax=plt.subplot(2,3,6)
err3 = np.max(err_mat[bad_idx,:,:],axis = 0)
plt.title("Maximum MSE",fontsize=15,y=1.04)
plt.imshow(err3)#,norm=LogNorm(vmin=err3.min(), vmax=err3.max()))
plt.colorbar(format=mtick.PercentFormatter())
ax.set_xticks(np.linspace(0,Nstrikes-1,Nstrikes))
ax.set_xticklabels(strikes)
ax.set_yticks(np.linspace(0,Nmaturities-1,Nmaturities))
ax.set_yticklabels(maturities)
plt.xlabel("Strike",fontsize=15,labelpad=5)
plt.ylabel("Maturity",fontsize=15,labelpad=5)
plt.setp(ax.get_xticklabels(), rotation=30, horizontalalignment='right')
plt.tight_layout()
plt.show()

# %% [markdown]
# # 3. CNN as  Decoder/Inverse Mapping

# %%
# reshaping for cnn purposes
y_train_trafo2 = y_train_trafo.reshape((Ntrain,Nmaturities,Nstrikes,1))
y_test_trafo2 = y_test_trafo.reshape((Ntest,Nmaturities,Nstrikes,1))
y_val_trafo2 = y_val_trafo.reshape((Nval,Nmaturities,Nstrikes,1))
X_val_trafo2 = X_val_trafo.reshape((Nval,Nparameters))
X_train_trafo2 = X_train_trafo.reshape((Ntrain,Nparameters))
X_test_trafo2 = X_test_trafo.reshape((Ntest,Nparameters))
""" old structure with multi-purpose network 
input1 = Input(shape = (7,9,1))
x1 = Conv2D(64, kernel_size=3, activation='relu')(input1)
x2 = Conv2D(64, kernel_size=3, activation='relu')(x1)
x3 = Flatten()(x2)
x4 = Dense(50, activation = 'elu')(x3)
seq1 = Dense(1, activation = 'linear',use_bias=True)(x4)
seq2 = Dense(1, activation = 'linear',use_bias=True)(x4)
seq3 = Dense(1, activation = 'linear',use_bias=True)(x4)
seq4 = Dense(1, activation = 'linear',use_bias=True)(x4)
seq5 = Dense(1, activation = 'linear',use_bias=True)(x4)
out1 = keras.layers.merge.concatenate([seq1, seq2, seq3,seq4,seq5], axis=-1)
NN2 = Model(inputs=input1, outputs=out1)
"""
NN2 = Sequential() 
NN2.add(InputLayer(input_shape=(Nmaturities,Nstrikes,1)))
NN2.add(Conv2D(64,(3, 3),padding='valid',strides =(1,1),activation ='tanh'))
NN2.add(Conv2D(64,(2, 2),padding='valid',strides =(1,1),activation ='tanh'))
NN2.add(MaxPooling2D(pool_size=(2, 2)))
NN2.add(Conv2D(64,(2, 2),padding='valid',strides =(1,1),activation ='tanh'))
NN2.add(ZeroPadding2D(padding=(1,1)))
NN2.add(Conv2D(64,(2, 2),padding='valid',strides =(1,1),activation ='tanh'))
NN2.add(ZeroPadding2D(padding=(1,1)))
NN2.add(Conv2D(64,(2, 2),padding='valid',strides =(1,1),activation ='tanh'))
NN2.add(Conv2D(64,(2, 2),padding='valid',strides =(1,1),activation ='tanh'))
NN2.add(ZeroPadding2D(padding=(1,1)))
NN2.add(Conv2D(64,(2, 2),padding='valid',strides =(1,1),activation ='tanh'))
NN2.add(ZeroPadding2D(padding=(1,1)))
NN2.add(Conv2D(64,(2, 2),padding='valid',strides =(1,1),activation ='tanh'))

NN2.add(Flatten())
NN2.add(Dense(5,activation = 'linear',use_bias=True))
NN2.summary()
#NN2.compile(loss = root_relative_mean_squared_error, optimizer = "adam",metrics=["MAPE","MSE"])
NN2.compile(loss ="MSE", optimizer = "adam",metrics=["MAPE", root_relative_mean_squared_error])

NN2.fit(y_train_trafo2,X_train_trafo2, batch_size=50, validation_data = (y_val_trafo2,X_val_trafo2),
        epochs = 50, verbose = True, shuffle=1)
# Out:
# WARNING:tensorflow:From D:\Programme\Anaconda\lib\site-packages\keras\backend\tensorflow_backend.py:3976: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_8 (Conv2D)            (None, 5, 7, 64)          640
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 4, 6, 64)          16448
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 2, 3, 64)          0
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 1, 2, 64)          16448
# _________________________________________________________________
# zero_padding2d_6 (ZeroPaddin (None, 3, 4, 64)          0
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 2, 3, 64)          16448
# _________________________________________________________________
# zero_padding2d_7 (ZeroPaddin (None, 4, 5, 64)          0
# _________________________________________________________________
# conv2d_12 (Conv2D)           (None, 3, 4, 64)          16448
# _________________________________________________________________
# conv2d_13 (Conv2D)           (None, 2, 3, 64)          16448
# _________________________________________________________________
# zero_padding2d_8 (ZeroPaddin (None, 4, 5, 64)          0
# _________________________________________________________________
# conv2d_14 (Conv2D)           (None, 3, 4, 64)          16448
# _________________________________________________________________
# zero_padding2d_9 (ZeroPaddin (None, 5, 6, 64)          0
# _________________________________________________________________
# conv2d_15 (Conv2D)           (None, 4, 5, 64)          16448
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 1280)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 5)                 6405
# =================================================================
# Total params: 122,181
# Trainable params: 122,181
# Non-trainable params: 0
# _________________________________________________________________
# Train on 36085 samples, validate on 6369 samples
# Epoch 1/50
# 36085/36085 [==============================] - 24s 675us/step - loss: 0.2065 - mean_absolute_percentage_error: 217.1102 - root_relative_mean_squared_error: 17.0229 - val_loss: 0.1424 - val_mean_absolute_percentage_error: 192.9500 - val_root_relative_mean_squared_error: 14.9064
# Epoch 2/50
# 36085/36085 [==============================] - 23s 626us/step - loss: 0.1278 - mean_absolute_percentage_error: 297.9888 - root_relative_mean_squared_error: 32.0943 - val_loss: 0.1216 - val_mean_absolute_percentage_error: 156.0657 - val_root_relative_mean_squared_error: 9.9897
# Epoch 3/50
# 36085/36085 [==============================] - 26s 722us/step - loss: 0.1177 - mean_absolute_percentage_error: 276.8771 - root_relative_mean_squared_error: 29.4800 - val_loss: 0.1167 - val_mean_absolute_percentage_error: 168.2451 - val_root_relative_mean_squared_error: 12.3817
# Epoch 4/50
# 36085/36085 [==============================] - 24s 665us/step - loss: 0.1111 - mean_absolute_percentage_error: 236.2016 - root_relative_mean_squared_error: 23.5015 - val_loss: 0.1091 - val_mean_absolute_percentage_error: 152.8172 - val_root_relative_mean_squared_error: 11.6928
# Epoch 5/50
# 36085/36085 [==============================] - 24s 659us/step - loss: 0.1041 - mean_absolute_percentage_error: 245.4050 - root_relative_mean_squared_error: 25.8002 - val_loss: 0.1115 - val_mean_absolute_percentage_error: 201.3375 - val_root_relative_mean_squared_error: 18.7765
# Epoch 6/50
# 36085/36085 [==============================] - 23s 643us/step - loss: 0.0976 - mean_absolute_percentage_error: 228.8260 - root_relative_mean_squared_error: 23.7903 - val_loss: 0.0899 - val_mean_absolute_percentage_error: 128.5525 - val_root_relative_mean_squared_error: 9.0664
# Epoch 7/50
# 36085/36085 [==============================] - 23s 644us/step - loss: 0.0942 - mean_absolute_percentage_error: 199.9659 - root_relative_mean_squared_error: 19.7796 - val_loss: 0.0915 - val_mean_absolute_percentage_error: 120.6995 - val_root_relative_mean_squared_error: 9.4335
# Epoch 8/50
# 36085/36085 [==============================] - 26s 728us/step - loss: 0.0909 - mean_absolute_percentage_error: 219.2656 - root_relative_mean_squared_error: 23.2602 - val_loss: 0.0905 - val_mean_absolute_percentage_error: 139.7715 - val_root_relative_mean_squared_error: 10.3062
# Epoch 9/50
# 36085/36085 [==============================] - 23s 643us/step - loss: 0.0877 - mean_absolute_percentage_error: 169.0294 - root_relative_mean_squared_error: 15.7991 - val_loss: 0.0920 - val_mean_absolute_percentage_error: 133.5257 - val_root_relative_mean_squared_error: 10.6410
# Epoch 10/50
# 36085/36085 [==============================] - 24s 676us/step - loss: 0.0858 - mean_absolute_percentage_error: 139.5703 - root_relative_mean_squared_error: 11.6096 - val_loss: 0.0853 - val_mean_absolute_percentage_error: 102.8730 - val_root_relative_mean_squared_error: 7.4893
# Epoch 11/50
# 36085/36085 [==============================] - 23s 640us/step - loss: 0.0839 - mean_absolute_percentage_error: 146.4177 - root_relative_mean_squared_error: 13.3480 - val_loss: 0.0899 - val_mean_absolute_percentage_error: 142.8306 - val_root_relative_mean_squared_error: 10.7102
# Epoch 12/50
# 36085/36085 [==============================] - 25s 699us/step - loss: 0.0824 - mean_absolute_percentage_error: 185.1661 - root_relative_mean_squared_error: 19.7854 - val_loss: 0.0791 - val_mean_absolute_percentage_error: 111.2344 - val_root_relative_mean_squared_error: 8.8467
# Epoch 13/50
# 36085/36085 [==============================] - 27s 754us/step - loss: 0.0814 - mean_absolute_percentage_error: 199.6294 - root_relative_mean_squared_error: 22.2167 - val_loss: 0.0789 - val_mean_absolute_percentage_error: 92.2417 - val_root_relative_mean_squared_error: 6.3851
# Epoch 14/50
# 36085/36085 [==============================] - 23s 631us/step - loss: 0.0820 - mean_absolute_percentage_error: 194.6115 - root_relative_mean_squared_error: 21.2663 - val_loss: 0.0827 - val_mean_absolute_percentage_error: 128.6223 - val_root_relative_mean_squared_error: 10.5509
# Epoch 15/50
# 36085/36085 [==============================] - 24s 668us/step - loss: 0.0803 - mean_absolute_percentage_error: 136.5170 - root_relative_mean_squared_error: 12.5310 - val_loss: 0.1064 - val_mean_absolute_percentage_error: 130.7774 - val_root_relative_mean_squared_error: 9.1564
# Epoch 16/50
# 36085/36085 [==============================] - 23s 637us/step - loss: 0.0803 - mean_absolute_percentage_error: 149.9905 - root_relative_mean_squared_error: 14.6687 - val_loss: 0.0756 - val_mean_absolute_percentage_error: 80.4204 - val_root_relative_mean_squared_error: 5.0544
# Epoch 17/50
# 36085/36085 [==============================] - 23s 633us/step - loss: 0.0797 - mean_absolute_percentage_error: 180.0681 - root_relative_mean_squared_error: 19.5917 - val_loss: 0.0808 - val_mean_absolute_percentage_error: 109.9778 - val_root_relative_mean_squared_error: 8.0104
# Epoch 18/50
# 36085/36085 [==============================] - 27s 735us/step - loss: 0.0781 - mean_absolute_percentage_error: 158.6160 - root_relative_mean_squared_error: 16.6440 - val_loss: 0.0802 - val_mean_absolute_percentage_error: 123.6007 - val_root_relative_mean_squared_error: 9.7823rror: 162.7254 -
# Epoch 19/50
# 36085/36085 [==============================] - 23s 631us/step - loss: 0.0785 - mean_absolute_percentage_error: 146.5968 - root_relative_mean_squared_error: 14.6431 - val_loss: 0.0752 - val_mean_absolute_percentage_error: 75.1000 - val_root_relative_mean_squared_error: 5.0986
# Epoch 20/50
# 36085/36085 [==============================] - 23s 649us/step - loss: 0.0779 - mean_absolute_percentage_error: 125.5341 - root_relative_mean_squared_error: 11.4961 - val_loss: 0.0800 - val_mean_absolute_percentage_error: 81.7156 - val_root_relative_mean_squared_error: 5.6862
# Epoch 21/50
# 36085/36085 [==============================] - 23s 624us/step - loss: 0.0782 - mean_absolute_percentage_error: 170.7632 - root_relative_mean_squared_error: 18.4932 - val_loss: 0.0765 - val_mean_absolute_percentage_error: 88.1678 - val_root_relative_mean_squared_error: 6.1697
# Epoch 22/50
# 36085/36085 [==============================] - 23s 633us/step - loss: 0.0781 - mean_absolute_percentage_error: 131.0682 - root_relative_mean_squared_error: 12.2577 - val_loss: 0.0841 - val_mean_absolute_percentage_error: 113.7698 - val_root_relative_mean_squared_error: 8.8089
# Epoch 23/50
# 36085/36085 [==============================] - 27s 739us/step - loss: 0.0781 - mean_absolute_percentage_error: 144.6308 - root_relative_mean_squared_error: 14.3105 - val_loss: 0.0831 - val_mean_absolute_percentage_error: 99.9171 - val_root_relative_mean_squared_error: 7.2386
# Epoch 24/50
# 36085/36085 [==============================] - 23s 626us/step - loss: 0.0764 - mean_absolute_percentage_error: 176.9129 - root_relative_mean_squared_error: 20.0372 - val_loss: 0.0739 - val_mean_absolute_percentage_error: 69.9325 - val_root_relative_mean_squared_error: 4.1874
# Epoch 25/50
# 36085/36085 [==============================] - 23s 641us/step - loss: 0.0766 - mean_absolute_percentage_error: 149.5251 - root_relative_mean_squared_error: 15.6311 - val_loss: 0.0764 - val_mean_absolute_percentage_error: 87.8908 - val_root_relative_mean_squared_error: 6.0261
# Epoch 26/50
# 36085/36085 [==============================] - 23s 628us/step - loss: 0.0760 - mean_absolute_percentage_error: 155.4602 - root_relative_mean_squared_error: 16.8272 - val_loss: 0.0761 - val_mean_absolute_percentage_error: 99.2994 - val_root_relative_mean_squared_error: 7.2472
# Epoch 27/50
# 36085/36085 [==============================] - 23s 629us/step - loss: 0.0763 - mean_absolute_percentage_error: 143.4007 - root_relative_mean_squared_error: 14.7444 - val_loss: 0.0759 - val_mean_absolute_percentage_error: 100.6560 - val_root_relative_mean_squared_error: 8.4207
# Epoch 28/50
# 36085/36085 [==============================] - 26s 731us/step - loss: 0.0762 - mean_absolute_percentage_error: 119.7608 - root_relative_mean_squared_error: 11.0208 - val_loss: 0.0759 - val_mean_absolute_percentage_error: 98.8644 - val_root_relative_mean_squared_error: 7.3911 120.0882 - root_relative_mean_squared_
# Epoch 29/50
# 36085/36085 [==============================] - 23s 626us/step - loss: 0.0775 - mean_absolute_percentage_error: 196.3048 - root_relative_mean_squared_error: 22.7986 - val_loss: 0.0768 - val_mean_absolute_percentage_error: 85.7870 - val_root_relative_mean_squared_error: 5.9296
# Epoch 30/50
# 36085/36085 [==============================] - 23s 647us/step - loss: 0.0755 - mean_absolute_percentage_error: 141.0130 - root_relative_mean_squared_error: 14.6561 - val_loss: 0.0770 - val_mean_absolute_percentage_error: 84.5647 - val_root_relative_mean_squared_error: 5.5829
# Epoch 31/50
# 36085/36085 [==============================] - 23s 632us/step - loss: 0.0758 - mean_absolute_percentage_error: 170.4229 - root_relative_mean_squared_error: 19.1948 - val_loss: 0.0751 - val_mean_absolute_percentage_error: 94.0820 - val_root_relative_mean_squared_error: 7.2170
# Epoch 32/50
# 36085/36085 [==============================] - 23s 627us/step - loss: 0.0755 - mean_absolute_percentage_error: 155.2555 - root_relative_mean_squared_error: 16.8012 - val_loss: 0.0794 - val_mean_absolute_percentage_error: 99.1401 - val_root_relative_mean_squared_error: 6.4558
# Epoch 33/50
# 36085/36085 [==============================] - 27s 735us/step - loss: 0.0765 - mean_absolute_percentage_error: 149.7549 - root_relative_mean_squared_error: 15.7032 - val_loss: 0.0738 - val_mean_absolute_percentage_error: 89.5615 - val_root_relative_mean_squared_error: 7.5595
# Epoch 34/50
# 36085/36085 [==============================] - 23s 634us/step - loss: 0.0763 - mean_absolute_percentage_error: 132.5191 - root_relative_mean_squared_error: 13.0518 - val_loss: 0.0768 - val_mean_absolute_percentage_error: 98.6277 - val_root_relative_mean_squared_error: 7.8805
# Epoch 35/50
# 36085/36085 [==============================] - 23s 631us/step - loss: 0.0750 - mean_absolute_percentage_error: 103.6052 - root_relative_mean_squared_error: 8.8517 - val_loss: 0.0736 - val_mean_absolute_percentage_error: 77.5842 - val_root_relative_mean_squared_error: 4.7538
# Epoch 36/50
# 36085/36085 [==============================] - 23s 641us/step - loss: 0.0751 - mean_absolute_percentage_error: 151.7498 - root_relative_mean_squared_error: 16.5644 - val_loss: 0.0762 - val_mean_absolute_percentage_error: 86.9248 - val_root_relative_mean_squared_error: 7.0093
# Epoch 37/50
# 36085/36085 [==============================] - 23s 631us/step - loss: 0.0751 - mean_absolute_percentage_error: 125.3383 - root_relative_mean_squared_error: 12.2442 - val_loss: 0.0778 - val_mean_absolute_percentage_error: 87.9420 - val_root_relative_mean_squared_error: 6.2571solute_percentage_error: 140.3405 - root_relative_mean_squa - ETA: 4s - loss: 0.0754 - mean_absolute_ - ETA: 2s - loss: 0.0754 - mean_absolute_percentage_error: 13 - ETA: 0s - loss: 0.0752 - mean_absolute_percentage_error: 127.2735 - root_re
# Epoch 38/50
# 36085/36085 [==============================] - 26s 722us/step - loss: 0.0760 - mean_absolute_percentage_error: 148.3169 - root_relative_mean_squared_error: 15.5984 - val_loss: 0.0752 - val_mean_absolute_percentage_error: 79.2521 - val_root_relative_mean_squared_error: 4.9244
# Epoch 39/50
# 36085/36085 [==============================] - 24s 652us/step - loss: 0.0745 - mean_absolute_percentage_error: 102.4218 - root_relative_mean_squared_error: 8.8384 - val_loss: 0.0747 - val_mean_absolute_percentage_error: 72.9999 - val_root_relative_mean_squared_error: 4.0099
# Epoch 40/50
# 36085/36085 [==============================] - 23s 648us/step - loss: 0.0745 - mean_absolute_percentage_error: 129.9946 - root_relative_mean_squared_error: 13.2467 - val_loss: 0.0776 - val_mean_absolute_percentage_error: 81.2348 - val_root_relative_mean_squared_error: 4.9053
# Epoch 41/50
# 36085/36085 [==============================] - 23s 640us/step - loss: 0.0751 - mean_absolute_percentage_error: 99.6555 - root_relative_mean_squared_error: 8.2719 - val_loss: 0.0748 - val_mean_absolute_percentage_error: 84.1313 - val_root_relative_mean_squared_error: 5.9426
# Epoch 42/50
# 36085/36085 [==============================] - 24s 663us/step - loss: 0.0749 - mean_absolute_percentage_error: 120.5741 - root_relative_mean_squared_error: 11.5877 - val_loss: 0.0726 - val_mean_absolute_percentage_error: 77.5519 - val_root_relative_mean_squared_error: 5.9733
# Epoch 43/50
# 36085/36085 [==============================] - 27s 751us/step - loss: 0.0739 - mean_absolute_percentage_error: 99.2837 - root_relative_mean_squared_error: 8.4575 - val_loss: 0.0771 - val_mean_absolute_percentage_error: 78.1880 - val_root_relative_mean_squared_error: 4.8594
# Epoch 44/50
# 36085/36085 [==============================] - 23s 629us/step - loss: 0.0742 - mean_absolute_percentage_error: 109.5777 - root_relative_mean_squared_error: 10.1511 - val_loss: 0.0743 - val_mean_absolute_percentage_error: 81.9936 - val_root_relative_mean_squared_error: 5.5268
# Epoch 45/50
# 36085/36085 [==============================] - 24s 659us/step - loss: 0.0743 - mean_absolute_percentage_error: 129.6516 - root_relative_mean_squared_error: 13.2737 - val_loss: 0.0730 - val_mean_absolute_percentage_error: 75.1052 - val_root_relative_mean_squared_error: 4.7926
# Epoch 46/50
# 36085/36085 [==============================] - 23s 649us/step - loss: 0.0739 - mean_absolute_percentage_error: 131.4739 - root_relative_mean_squared_error: 13.6188 - val_loss: 0.0753 - val_mean_absolute_percentage_error: 79.6714 - val_root_relative_mean_squared_error: 5.6520
# Epoch 47/50
# 36085/36085 [==============================] - 23s 635us/step - loss: 0.0740 - mean_absolute_percentage_error: 181.5618 - root_relative_mean_squared_error: 21.4994 - val_loss: 0.0731 - val_mean_absolute_percentage_error: 69.3601 - val_root_relative_mean_squared_error: 4.0626rr - ETA: 2s - l
# Epoch 48/50
# 36085/36085 [==============================] - 27s 746us/step - loss: 0.0752 - mean_absolute_percentage_error: 105.3880 - root_relative_mean_squared_error: 9.1415 - val_loss: 0.0763 - val_mean_absolute_percentage_error: 88.0106 - val_root_relative_mean_squared_error: 5.9740er - ETA: 0s - loss: 0.0752 - mean_absolute_percentage_error: 105.7871 - root_relative_mean_squared_error
# Epoch 49/50
# 36085/36085 [==============================] - 24s 656us/step - loss: 0.0733 - mean_absolute_percentage_error: 110.2543 - root_relative_mean_squared_error: 10.5847 - val_loss: 0.0744 - val_mean_absolute_percentage_error: 71.2831 - val_root_relative_mean_squared_error: 4.6856
# Epoch 50/50
# 36085/36085 [==============================] - 23s 632us/step - loss: 0.0746 - mean_absolute_percentage_error: 84.7176 - root_relative_mean_squared_error: 5.9433 - val_loss: 0.0754 - val_mean_absolute_percentage_error: 80.3236 - val_root_relative_mean_squared_error: 5.178445 - mean_absolute_percentage_error: 83.4

# %% [markdown]
# ### 3.1 Results
# Take care these results are on scaled parameter values and not rescaled yet!

# %%
prediction = NN2.predict(y_test_trafo2)
prediction_std = np.std(prediction,axis=0)
error = np.zeros((Ntest,Nparameters))
for i in range(Ntest):
    error[i,:] =  np.abs((X_test_trafo2[i,:]-prediction[i,:])/X_test_trafo2[i,:])
err1 = np.mean(error,axis = 0)
err2 = np.median(error,axis = 0)
err_std = np.std(error,axis = 0)
idx = np.argsort(error[:,0], axis=None)
good_idx = idx[:-100]
plt.boxplot(error)
plt.xticks([1, 2, 3,4,5], ['w','a','b','g*','h0'])
plt.show()
print("error mean in %:",100*err1)
print("error median in %:",100*err2)
# Out:
# error mean in %: [ 45.25798035 117.93339961  28.26985738 132.57018178 101.35927712]
# error median in %: [  7.34670022  13.3883384    3.02493541 100.33809012   9.58792251]

# %% [markdown]
# # 4. FFNN as Encoder - Approach of Horvath (improved)

# %%
#to be copied to this file. Compare NN_henrik_old.py

# %% [markdown]
# # 5. Testing the performace of the AutoEncoder/Decoder Combination
# We test how the two previously trained NN work together. First, HNG-Vola surfaces are used to predict the underlying parameters with NN2. Those predictions are fed into NN1 to get Vola-Surface again. The results are shown below.

# %%
prediction_trafo = prediction.reshape((Ntest,Nparameters,1,1))
forecast = NN1.predict(prediction_trafo).reshape(Ntest,Nmaturities,Nstrikes)
y_true_test = y_test_trafo2.reshape(Ntest,Nmaturities,Nstrikes)
# Example Plots
X = strikes
Y = maturities
X, Y = np.meshgrid(X, Y)
from mpl_toolkits.mplot3d import Axes3D  
from matplotlib import cm
import random
sample_idx = random.randint(0,len(y_test))
fig = plt.figure()
ax = fig.gca(projection='3d')
#ax.contour3D(X, Y, Z, 50, cmap='binary')
ax.plot_surface(X, Y, y_true_test[sample_idx,:,:], rstride=1, cstride=1,
                cmap='viridis', edgecolor='none')
ax.plot_surface(X, Y, forecast[sample_idx,:,:] , rstride=1, cstride=1,
                cmap='viridis', edgecolor='none')
ax.set_xlabel('Strikes')
ax.set_ylabel('Maturities')
plt.show()
#error plots
mape = np.zeros(forecast.shape)
mse  = np.zeros(forecast.shape)
for i in range(Ntest):
    mape[i,:,:] =  np.abs((y_true_test[i,:,:]-forecast[i,:,:])/y_true_test[i,:,:])
    mse[i,:,:]  =  np.square((y_true_test[i,:,:]-forecast[i,:,:]))
idx = np.argsort(np.max(err_rel_mat,axis=tuple([1,2])), axis=None)

#bad_idx = idx[:-200]
bad_idx = idx
#from matplotlib.colors import LogNorm
plt.figure(figsize=(14,4))
ax=plt.subplot(2,3,1)
err1 = 100*np.mean(mape[bad_idx,:,:],axis=0)
plt.title("Average relative error",fontsize=15,y=1.04)
plt.imshow(err1)#,norm=LogNorm(vmin=err1.min(), vmax=err1.max()))
plt.setp(ax.get_xticklabels(), rotation=30, horizontalalignment='right')
plt.colorbar(format=mtick.PercentFormatter())
ax.set_xticks(np.linspace(0,Nstrikes-1,Nstrikes))
ax.set_xticklabels(strikes)
ax.set_yticks(np.linspace(0,Nmaturities-1,Nmaturities))
ax.set_yticklabels(maturities)
plt.xlabel("Strike",fontsize=15,labelpad=5)
plt.ylabel("Maturity",fontsize=15,labelpad=5)
ax=plt.subplot(2,3,2)
err2 = 100*np.std(mape[bad_idx,:,:],axis = 0)
plt.title("Std relative error",fontsize=15,y=1.04)
plt.imshow(err2)#,norm=LogNorm(vmin=err2.min(), vmax=err2.max()))
plt.colorbar(format=mtick.PercentFormatter())
plt.setp(ax.get_xticklabels(), rotation=30, horizontalalignment='right')
ax.set_xticks(np.linspace(0,Nstrikes-1,Nstrikes))
ax.set_xticklabels(strikes)
ax.set_yticks(np.linspace(0,Nmaturities-1,Nmaturities))
ax.set_yticklabels(maturities)
plt.xlabel("Strike",fontsize=15,labelpad=5)
plt.ylabel("Maturity",fontsize=15,labelpad=5)
ax=plt.subplot(2,3,3)
err3 = 100*np.max(mape[bad_idx,:,:],axis = 0)
plt.title("Maximum relative error",fontsize=15,y=1.04)
plt.imshow(err3)#,norm=LogNorm(vmin=err3.min(), vmax=err3.max()))
plt.colorbar(format=mtick.PercentFormatter())
plt.setp(ax.get_xticklabels(), rotation=30, horizontalalignment='right')
ax.set_xticks(np.linspace(0,Nstrikes-1,Nstrikes))
ax.set_xticklabels(strikes)
ax.set_yticks(np.linspace(0,Nmaturities-1,Nmaturities))
ax.set_yticklabels(maturities)
plt.xlabel("Strike",fontsize=15,labelpad=5)
plt.ylabel("Maturity",fontsize=15,labelpad=5)
ax=plt.subplot(2,3,4)
err1 = np.sqrt(np.mean(mse[bad_idx,:,:],axis=0))
plt.title("RMSE",fontsize=15,y=1.04)
plt.imshow(err1)#,norm=LogNorm(vmin=err1.min(), vmax=err1.max()))
plt.colorbar(format=mtick.PercentFormatter())
plt.setp(ax.get_xticklabels(), rotation=30, horizontalalignment='right')
ax.set_xticks(np.linspace(0,Nstrikes-1,Nstrikes))
ax.set_xticklabels(strikes)
ax.set_yticks(np.linspace(0,Nmaturities-1,Nmaturities))
ax.set_yticklabels(maturities)
plt.xlabel("Strike",fontsize=15,labelpad=5)
plt.ylabel("Maturity",fontsize=15,labelpad=5)
ax=plt.subplot(2,3,5)
err2 = np.std(mse[bad_idx,:,:],axis = 0)
plt.title("Std MSE",fontsize=15,y=1.04)
plt.imshow(err2)#,norm=LogNorm(vmin=err2.min(), vmax=err2.max()))
plt.colorbar(format=mtick.PercentFormatter())
plt.setp(ax.get_xticklabels(), rotation=30, horizontalalignment='right')
ax.set_xticks(np.linspace(0,Nstrikes-1,Nstrikes))
ax.set_xticklabels(strikes)
ax.set_yticks(np.linspace(0,Nmaturities-1,Nmaturities))
ax.set_yticklabels(maturities)
plt.xlabel("Strike",fontsize=15,labelpad=5)
plt.ylabel("Maturity",fontsize=15,labelpad=5)
ax=plt.subplot(2,3,6)
err3 = np.max(mse[bad_idx,:,:],axis = 0)
plt.title("Maximum MSE",fontsize=15,y=1.04)
plt.imshow(err3)#,norm=LogNorm(vmin=err3.min(), vmax=err3.max()))
plt.colorbar(format=mtick.PercentFormatter())
ax.set_xticks(np.linspace(0,Nstrikes-1,Nstrikes))
ax.set_xticklabels(strikes)
ax.set_yticks(np.linspace(0,Nmaturities-1,Nmaturities))
ax.set_yticklabels(maturities)
plt.xlabel("Strike",fontsize=15,labelpad=5)
plt.ylabel("Maturity",fontsize=15,labelpad=5)
plt.setp(ax.get_xticklabels(), rotation=30, horizontalalignment='right')
plt.tight_layout()
plt.show()
