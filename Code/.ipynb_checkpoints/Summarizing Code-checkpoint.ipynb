# %% [markdown]
# # Summary
# __The Calibration Network / Inverse Mapping penalises now constraint violations!__
#
#
# This code gives a short summary on the current progress (last update: 20.01.2020).
# In the following a CNN aswell as a FFNN are trained to learn the mapping HNG-Parameters (w,a,b,g*,h0) to HNG-Volatility surface. A first approach on  training the inverse mapping with CNN is given.
# For the used dataset (50.000 szenarios), each szenario is generated as followed:
# S&P500 returns are used to get optimal HNG parameters for each week in 2015 (10years rolling window). The initial variance is used as variable aswell.
# Afterwards for each week in 2015 Call Prices are used to get optimal HNG parameters. The initial variance is set to the corrensponding value from MLE optimization.
# Those 52 optimal parameters combinations are then used as bounds.
# To generate a szenario a random value between the bounds is uniformly choosen (initial variance included)
# and a grid of implied variance is calculated for Maturities [30, 60, 90, 120, 150, 180, 210] days and Moneyness     [0.9, 0.925, 0.95, 0.975, 1.0, 1.025, 1.05, 1.075, 1.1].

# %% [markdown]
# # 1. Preambel and Data Import

# %%
# Preambel
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import keras
from keras.models import Sequential,Model
from keras.layers import InputLayer,Dense,Flatten, Conv2D, Dropout, Input,ZeroPadding2D,MaxPooling2D
from keras import backend as K
import matplotlib.pyplot as plt
import matplotlib.ticker as mtick
#import py_vollib.black_scholes.implied_volatility as vol
#import time
import scipy
import scipy.io
import tensorflow as tf

# scaler
def ytransform(y_train,y_val,y_test):
    #return [scale.transform(y_train),scale.transform(y_val), 
    #        scale.transform(y_test)]
    return [y_train,y_val,y_test]

def yinversetransform(y):
    return y
    #return scale.inverse_transform(y)
    
def myscale(x):
    res=np.zeros(Nparameters)
    for i in range(Nparameters):
        res[i]=(x[i] - (ub[i] + lb[i])*0.5) * 2 / (ub[i] - lb[i])
    return res

def myinverse(x):
    res=np.zeros(Nparameters)
    for i in range(Nparameters):
        res[i]=x[i]*(ub[i] - lb[i]) *0.5 + (ub[i] + lb[i])*0.5
    return res

def root_mean_squared_error(y_true, y_pred):
        return K.sqrt(K.mean(K.square(y_pred - y_true)))   
def root_relative_mean_squared_error(y_true, y_pred):
        return K.sqrt(K.mean(K.square((y_pred - y_true)/y_true)))   

def rmse_constraint(param):
    def rel_mse_constraint(y_true, y_pred):
            traf_a = 0.5*(y_pred[:,0]*diff[0]+bound_sum[0])
            traf_g = 0.5*(y_pred[:,2]*diff[2]+bound_sum[2])
            traf_b = 0.5*(y_pred[:,1]*diff[1]+bound_sum[1])
            constraint = traf_a*K.square(traf_g)+traf_b
            #constraint = K.variable(value=constraint, dtype='float64')
            return K.sqrt(K.mean(K.square((y_pred - y_true)/y_true)))  +param*K.mean(K.greater(constraint,1))
    return rel_mse_constraint
def mse_constraint(param):
    def rel_mse_constraint(y_true, y_pred):
            traf_a = 0.5*(y_pred[:,0]*diff[0]+bound_sum[0])
            traf_g = 0.5*(y_pred[:,2]*diff[2]+bound_sum[2])
            traf_b = 0.5*(y_pred[:,1]*diff[1]+bound_sum[1])
            constraint = traf_a*K.square(traf_g)+traf_b
            #constraint = K.variable(value=constraint, dtype='float64')
            return K.mean(K.square(y_pred - y_true)) +param*K.mean(K.greater(constraint,1))
    return rel_mse_constraint
    
# Data Import
mat         = scipy.io.loadmat('data_vola_maxbounds_50000_0005_09_11_30_210.mat')
data        = mat['data_vola']
Nparameters = 5
maturities  = np.array([30, 60, 90, 120, 150, 180, 210])
strikes     = np.array([0.9, 0.925, 0.95, 0.975, 1.0, 1.025, 1.05, 1.075, 1.1])
Nstrikes    = len(strikes)   
Nmaturities = len(maturities)   
xx          = data[:,:Nparameters]
yy          = data[:,Nparameters+2:]

ub=np.amax(xx, axis=0)
lb=np.amin(xx, axis=0)
diff = ub-lb
bound_sum =ub+lb

# split into train and test sample
X_train, X_test, y_train, y_test = train_test_split(
    xx, yy, test_size=0.15)#, random_state=42)

X_train, X_val, y_train, y_val = train_test_split(
   X_train, y_train, test_size=0.15)#, random_state=42)

Ntest= X_test.shape[0]
Ntrain= X_train.shape[0]
Nval= X_val.shape[0]
keras.backend.set_floatx('float64')
# Out:
# Using TensorFlow backend.

# %% [markdown]
# # 2. CNN as Encoder / Pricing Kernel

# %%
# reshaping train/test sets for structure purposes
[y_train_trafo, y_val_trafo, y_test_trafo]=ytransform(y_train, y_val, y_test)
y_train_trafo = np.asarray([y_train[i,:].reshape((1,Nmaturities,Nstrikes)) for i in range(Ntrain)])
y_val_trafo =  np.asarray([y_val[i,:].reshape((1,Nmaturities,Nstrikes)) for i in range(Nval)])
y_test_trafo =  np.asarray([y_test[i,:].reshape((1,Nmaturities,Nstrikes)) for i in range(Ntest)])

X_train_trafo = np.array([myscale(x) for x in X_train])
X_val_trafo   = np.array([myscale(x) for x in X_val])
X_test_trafo  = np.array([myscale(x) for x in X_test])
X_train_trafo = np.array([myscale(x) for x in X_train])
X_val_trafo   = np.array([myscale(x) for x in X_val])
X_test_trafo  = X_test_trafo.reshape((Ntest,5,1,1))
X_train_trafo = X_train_trafo.reshape((Ntrain,5,1,1))
X_val_trafo   = X_val_trafo.reshape((Nval,5,1,1))

# %%
NN1 = Sequential() 
NN1.add(InputLayer(input_shape=(Nparameters,1,1,)))
NN1.add(ZeroPadding2D(padding=(2, 2)))
NN1.add(Conv2D(32, (3, 1), padding='valid',use_bias =True,strides =(1,1),activation='elu'))#X_train_trafo.shape[1:],activation='elu'))
NN1.add(ZeroPadding2D(padding=(1,1)))
NN1.add(Conv2D(32, (2, 2),padding='valid',use_bias =True,strides =(1,1),activation ='elu'))
NN1.add(Conv2D(32, (2, 2),padding='valid',use_bias =True,strides =(2,1),activation ='elu'))
NN1.add(ZeroPadding2D(padding=(1,1)))
NN1.add(Conv2D(32, (3,3),padding='valid',use_bias =True,strides =(2,1),activation ='elu'))
NN1.add(ZeroPadding2D(padding=(1,1)))
NN1.add(Conv2D(32, (2, 2),padding='valid',use_bias =True,strides =(2,1),activation ='elu'))
NN1.add(ZeroPadding2D(padding=(1,1)))
NN1.add(Conv2D(32, (2, 2),padding='valid',use_bias =True,strides =(2,1),activation ='elu'))
#NN1.add(MaxPooling2D(pool_size=(2, 1)))
#NN1.add(Dropout(0.25))
#NN1.add(ZeroPadding2D(padding=(0,1)))
NN1.add(Conv2D(Nstrikes, (2, 1),padding='valid',use_bias =True,strides =(2,1),activation ='linear', kernel_constraint = keras.constraints.NonNeg()))
#NN1.add(MaxPooling2D(pool_size=(4, 1)))
NN1.summary()
NN1.compile(loss = root_relative_mean_squared_error, optimizer = "adam",metrics=["MAPE","MSE"])
NN1.fit(X_train_trafo, y_train_trafo, batch_size=64, validation_data = (X_val_trafo, y_val_trafo),
        epochs = 30, verbose = True, shuffle=1)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# zero_padding2d_13 (ZeroPaddi (None, 9, 5, 1)           0
# _________________________________________________________________
# conv2d_25 (Conv2D)           (None, 7, 5, 32)          128
# _________________________________________________________________
# zero_padding2d_14 (ZeroPaddi (None, 9, 7, 32)          0
# _________________________________________________________________
# conv2d_26 (Conv2D)           (None, 8, 6, 32)          4128
# _________________________________________________________________
# conv2d_27 (Conv2D)           (None, 4, 5, 32)          4128
# _________________________________________________________________
# zero_padding2d_15 (ZeroPaddi (None, 6, 7, 32)          0
# _________________________________________________________________
# conv2d_28 (Conv2D)           (None, 2, 5, 32)          9248
# _________________________________________________________________
# zero_padding2d_16 (ZeroPaddi (None, 4, 7, 32)          0
# _________________________________________________________________
# conv2d_29 (Conv2D)           (None, 2, 6, 32)          4128
# _________________________________________________________________
# zero_padding2d_17 (ZeroPaddi (None, 4, 8, 32)          0
# _________________________________________________________________
# conv2d_30 (Conv2D)           (None, 2, 7, 32)          4128
# _________________________________________________________________
# conv2d_31 (Conv2D)           (None, 1, 7, 9)           585
# =================================================================
# Total params: 26,473
# Trainable params: 26,473
# Non-trainable params: 0
# _________________________________________________________________
# Train on 36085 samples, validate on 6369 samples
# Epoch 1/30
# 36085/36085 [==============================] - 12s 336us/step - loss: 0.2407 - mean_absolute_percentage_error: 18.2669 - mean_squared_error: 0.0045 - val_loss: 0.2016 - val_mean_absolute_percentage_error: 14.9171 - val_mean_squared_error: 0.0036
# Epoch 2/30
# 36085/36085 [==============================] - 11s 303us/step - loss: 0.1964 - mean_absolute_percentage_error: 14.3533 - mean_squared_error: 0.0036 - val_loss: 0.1853 - val_mean_absolute_percentage_error: 13.2914 - val_mean_squared_error: 0.0034
# Epoch 3/30
# 36085/36085 [==============================] - 10s 268us/step - loss: 0
# 36085/36085 [==============================] - 10s 275us/step - loss: 0.0448 - mean_absolute_percentage_error: 2.9947 - mean_squared_error: 2.5677e-04 - val_loss: 0.0451 - val_mean_absolute_percentage_error: 3.2397 - val_mean_squared_error: 2.6282e-04
# Epoch 28/30
# 36085/36085 [==============================] - 10s 274us/step - loss: 0.0441 - mean_absolute_percentage_error: 2.9603 - mean_squared_error: 2.5994e-04 - val_loss: 0.0339 - val_mean_absolute_percentage_error: 2.1487 - val_mean_squared_error: 2.0402e-04
# Epoch 29/30
# 36085/36085 [==============================] - 10s 275us/step - loss: 0.0401 - mean_absolute_percentage_error: 2.6814 - mean_squared_error: 2.1577e-04 - val_loss: 0.0319 - val_mean_absolute_percentage_error: 2.1743 - val_mean_squared_error: 1.4757e-04
# Epoch 30/30
# 36085/36085 [==============================] - 10s 282us/step - loss: 0.0410 - mean_absolute_percentage_error: 2.7000 - mean_squared_error: 2.1947e-04 - val_loss: 0.0325 - val_mean_absolute_percentage_error: 2.0943 - val_mean_squared_error: 1.4218e-04

# %% [markdown]
# ### 2.1 Results
# The following plots show the performance on the testing set

# %%
#error plots
S0=1.
y_test_re    = yinversetransform(y_test_trafo).reshape((Ntest,Nmaturities,Nstrikes))
prediction   = NN1.predict(X_test_trafo).reshape((Ntest,Nmaturities,Nstrikes))
err_rel_mat  = np.zeros(prediction.shape)
err_mat      = np.zeros(prediction.shape)
for i in range(Ntest):
    err_rel_mat[i,:,:] =  np.abs((y_test_re[i,:,:]-prediction[i,:,:])/y_test_re[i,:,:])
    err_mat[i,:,:] =  np.square((y_test_re[i,:,:]-prediction[i,:,:]))
idx = np.argsort(np.max(err_rel_mat,axis=tuple([1,2])), axis=None)

#bad_idx = idx[:-200]
bad_idx = idx
#from matplotlib.colors import LogNorm
plt.figure(figsize=(14,4))
ax=plt.subplot(2,3,1)
err1 = 100*np.mean(err_rel_mat[bad_idx,:,:],axis=0)
plt.title("Average relative error",fontsize=15,y=1.04)
plt.imshow(err1)#,norm=LogNorm(vmin=err1.min(), vmax=err1.max()))
plt.setp(ax.get_xticklabels(), rotation=30, horizontalalignment='right')
plt.colorbar(format=mtick.PercentFormatter())
ax.set_xticks(np.linspace(0,Nstrikes-1,Nstrikes))
ax.set_xticklabels(strikes)
ax.set_yticks(np.linspace(0,Nmaturities-1,Nmaturities))
ax.set_yticklabels(maturities)
plt.xlabel("Strike",fontsize=15,labelpad=5)
plt.ylabel("Maturity",fontsize=15,labelpad=5)
ax=plt.subplot(2,3,2)
err2 = 100*np.std(err_rel_mat[bad_idx,:,:],axis = 0)
plt.title("Std relative error",fontsize=15,y=1.04)
plt.imshow(err2)#,norm=LogNorm(vmin=err2.min(), vmax=err2.max()))
plt.colorbar(format=mtick.PercentFormatter())
plt.setp(ax.get_xticklabels(), rotation=30, horizontalalignment='right')
ax.set_xticks(np.linspace(0,Nstrikes-1,Nstrikes))
ax.set_xticklabels(strikes)
ax.set_yticks(np.linspace(0,Nmaturities-1,Nmaturities))
ax.set_yticklabels(maturities)
plt.xlabel("Strike",fontsize=15,labelpad=5)
plt.ylabel("Maturity",fontsize=15,labelpad=5)
ax=plt.subplot(2,3,3)
err3 = 100*np.max(err_rel_mat[bad_idx,:,:],axis = 0)
plt.title("Maximum relative error",fontsize=15,y=1.04)
plt.imshow(err3)#,norm=LogNorm(vmin=err3.min(), vmax=err3.max()))
plt.colorbar(format=mtick.PercentFormatter())
plt.setp(ax.get_xticklabels(), rotation=30, horizontalalignment='right')
ax.set_xticks(np.linspace(0,Nstrikes-1,Nstrikes))
ax.set_xticklabels(strikes)
ax.set_yticks(np.linspace(0,Nmaturities-1,Nmaturities))
ax.set_yticklabels(maturities)
plt.xlabel("Strike",fontsize=15,labelpad=5)
plt.ylabel("Maturity",fontsize=15,labelpad=5)
ax=plt.subplot(2,3,4)
err1 = np.sqrt(np.mean(err_mat[bad_idx,:,:],axis=0))
plt.title("RMSE",fontsize=15,y=1.04)
plt.imshow(err1)#,norm=LogNorm(vmin=err1.min(), vmax=err1.max()))
plt.colorbar(format=mtick.PercentFormatter())
plt.setp(ax.get_xticklabels(), rotation=30, horizontalalignment='right')
ax.set_xticks(np.linspace(0,Nstrikes-1,Nstrikes))
ax.set_xticklabels(strikes)
ax.set_yticks(np.linspace(0,Nmaturities-1,Nmaturities))
ax.set_yticklabels(maturities)
plt.xlabel("Strike",fontsize=15,labelpad=5)
plt.ylabel("Maturity",fontsize=15,labelpad=5)
ax=plt.subplot(2,3,5)
err2 = np.std(err_mat[bad_idx,:,:],axis = 0)
plt.title("Std MSE",fontsize=15,y=1.04)
plt.imshow(err2)#,norm=LogNorm(vmin=err2.min(), vmax=err2.max()))
plt.colorbar(format=mtick.PercentFormatter())
plt.setp(ax.get_xticklabels(), rotation=30, horizontalalignment='right')
ax.set_xticks(np.linspace(0,Nstrikes-1,Nstrikes))
ax.set_xticklabels(strikes)
ax.set_yticks(np.linspace(0,Nmaturities-1,Nmaturities))
ax.set_yticklabels(maturities)
plt.xlabel("Strike",fontsize=15,labelpad=5)
plt.ylabel("Maturity",fontsize=15,labelpad=5)
ax=plt.subplot(2,3,6)
err3 = np.max(err_mat[bad_idx,:,:],axis = 0)
plt.title("Maximum MSE",fontsize=15,y=1.04)
plt.imshow(err3)#,norm=LogNorm(vmin=err3.min(), vmax=err3.max()))
plt.colorbar(format=mtick.PercentFormatter())
ax.set_xticks(np.linspace(0,Nstrikes-1,Nstrikes))
ax.set_xticklabels(strikes)
ax.set_yticks(np.linspace(0,Nmaturities-1,Nmaturities))
ax.set_yticklabels(maturities)
plt.xlabel("Strike",fontsize=15,labelpad=5)
plt.ylabel("Maturity",fontsize=15,labelpad=5)
plt.setp(ax.get_xticklabels(), rotation=30, horizontalalignment='right')
plt.tight_layout()
plt.show()

# %% [markdown]
# # 3. CNN as  Decoder/Inverse Mapping / Calibration

# %%
# reshaping for cnn purposes
y_train_trafo2 = y_train_trafo.reshape((Ntrain,Nmaturities,Nstrikes,1))
y_test_trafo2 = y_test_trafo.reshape((Ntest,Nmaturities,Nstrikes,1))
y_val_trafo2 = y_val_trafo.reshape((Nval,Nmaturities,Nstrikes,1))
X_val_trafo2 = X_val_trafo.reshape((Nval,Nparameters))
X_train_trafo2 = X_train_trafo.reshape((Ntrain,Nparameters))
X_test_trafo2 = X_test_trafo.reshape((Ntest,Nparameters))
""" old structure with multi-purpose network 
input1 = Input(shape = (7,9,1))
x1 = Conv2D(64, kernel_size=3, activation='relu')(input1)
x2 = Conv2D(64, kernel_size=3, activation='relu')(x1)
x3 = Flatten()(x2)
x4 = Dense(50, activation = 'elu')(x3)
seq1 = Dense(1, activation = 'linear',use_bias=True)(x4)
seq2 = Dense(1, activation = 'linear',use_bias=True)(x4)
seq3 = Dense(1, activation = 'linear',use_bias=True)(x4)
seq4 = Dense(1, activation = 'linear',use_bias=True)(x4)
seq5 = Dense(1, activation = 'linear',use_bias=True)(x4)
out1 = keras.layers.merge.concatenate([seq1, seq2, seq3,seq4,seq5], axis=-1)
NN2 = Model(inputs=input1, outputs=out1)
"""
# Out:
# " old structure with multi-purpose network \ninput1 = Input(shape = (7,9,1))\nx1 = Conv2D(64, kernel_size=3, activation='relu')(input1)\nx2 = Conv2D(64, kernel_size=3, activation='relu')(x1)\nx3 = Flatten()(x2)\nx4 = Dense(50, activation = 'elu')(x3)\nseq1 = Dense(1, activation = 'linear',use_bias=True)(x4)\nseq2 = Dense(1, activation = 'linear',use_bias=True)(x4)\nseq3 = Dense(1, activation = 'linear',use_bias=True)(x4)\nseq4 = Dense(1, activation = 'linear',use_bias=True)(x4)\nseq5 = Dense(1, activation = 'linear',use_bias=True)(x4)\nout1 = keras.layers.merge.concatenate([seq1, seq2, seq3,seq4,seq5], axis=-1)\nNN2 = Model(inputs=input1, outputs=out1)\n"

# %%
NN2 = Sequential() 
NN2.add(InputLayer(input_shape=(Nmaturities,Nstrikes,1)))
NN2.add(Conv2D(64,(3, 3),use_bias= True, padding='valid',strides =(1,1),activation ='tanh'))
NN2.add(Conv2D(64,(2, 2),use_bias= True,padding='valid',strides =(1,1),activation ='tanh'))
NN2.add(MaxPooling2D(pool_size=(2, 2)))
NN2.add(Conv2D(64,(2, 2),use_bias= True,padding='valid',strides =(1,1),activation ='tanh'))
NN2.add(ZeroPadding2D(padding=(1,1)))
NN2.add(Conv2D(64,(2, 2),use_bias= True,padding='valid',strides =(1,1),activation ='tanh'))
NN2.add(ZeroPadding2D(padding=(1,1)))
NN2.add(Conv2D(64,(2, 2),use_bias= True,padding='valid',strides =(1,1),activation ='tanh'))
NN2.add(Conv2D(64,(2, 2),use_bias= True,padding='valid',strides =(1,1),activation ='tanh'))
NN2.add(ZeroPadding2D(padding=(1,1)))
NN2.add(Conv2D(64,(2, 2),use_bias= True,padding='valid',strides =(1,1),activation ='tanh'))
NN2.add(ZeroPadding2D(padding=(1,1)))
NN2.add(Conv2D(64,(2, 2),use_bias= True,padding='valid',strides =(1,1),activation ='tanh'))
NN2.add(Flatten())
NN2.add(Dense(5,activation = 'linear',use_bias=True))
NN2.summary()


#NN2.compile(loss = root_relative_mean_squared_error, optimizer = "adam",metrics=["MAPE","MSE"])
NN2.compile(loss =mse_constraint(0.25), optimizer = "adam",metrics=["MAPE", "MSE"])
history = NN2.fit(y_train_trafo2,X_train_trafo2, batch_size=50, validation_data = (y_val_trafo2,X_val_trafo2),
    epochs=30, verbose = True, shuffle=1)
# Out:
# WARNING:tensorflow:From D:\Programme\Anaconda\lib\site-packages\keras\backend\tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From D:\Programme\Anaconda\lib\site-packages\keras\backend\tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From D:\Programme\Anaconda\lib\site-packages\keras\backend\tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From D:\Programme\Anaconda\lib\site-packages\keras\backend\tensorflow_backend.py:3976: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 5, 7, 64)          640
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 4, 6, 64)          16448
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 2, 3, 64)          0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 1, 2, 64)          16448
# _________________________________________________________________
# zero_padding2d_1 (ZeroPaddin (None, 3, 4, 64)          0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 2, 3, 64)          16448
# _________________________________________________________________
# zero_padding2d_2 (ZeroPaddin (None, 4, 5, 64)          0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 3, 4, 64)          16448
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 2, 3, 64)          16448
# _________________________________________________________________
# zero_padding2d_3 (ZeroPaddin (None, 4, 5, 64)          0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 3, 4, 64)          16448
# _________________________________________________________________
# zero_padding2d_4 (ZeroPaddin (None, 5, 6, 64)          0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 4, 5, 64)          16448
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 1280)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 5)                 6405
# =================================================================
# Total params: 122,181
# Trainable params: 122,181
# Non-trainable params: 0
# _________________________________________________________________
# WARNING:tensorflow:From D:\Programme\Anaconda\lib\site-packages\keras\optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# WARNING:tensorflow:From D:\Programme\Anaconda\lib\site-packages\keras\backend\tensorflow_backend.py:986: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# WARNING:tensorflow:From D:\Programme\Anaconda\lib\site-packages\keras\backend\tensorflow_backend.py:973: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# Train on 36085 samples, validate on 6369 samples
# Epoch 1/30
# 36085/36085 [==============================] - 22s 605us/step - loss: 0.2078 - mean_absolute_percentage_error: 208.6152 - mean_squared_error: 0.1871 - val_loss: 0.1564 - val_mean_absolute_percentage_error: 245.4962 - val_mean_squared_error: 0.1421
# Epoch 2/30
# 36085/36085 [==============================] - 21s 573us/step - loss: 0.1378 - mean_absolute_percentage_error: 234.0037 - mean_squared_error: 0.1244 - val_loss: 0.1448 - val_mean_absolute_percentage_error: 214.7957 - val_mean_squared_error: 0.1216
# Epoch 3/30
# 36085/36085 [==============================] - 20s 567us/step - loss: 0.1296 - mean_absolute_percentage_error: 227.6108 - mean_squared_error: 0.1162 - val_loss: 0.1236 - val_mean_absolute_percentage_error: 195.9921 - val_mean_squared_error: 0.1134
# Epoch 4/30
# 36085/36085 [==============================] - 20s 560us/step - loss: 0.1222 - mean_absolute_percentage_error: 262.5330 - mean_squared_error: 0.1096 - val_loss: 0.1211 - val_mean_absolute_percentage_error: 170.6360 - val_mean_squared_error: 0.1154
# Epoch 5/30
# 36085/36085 [==============================] - 20s 565us/step - loss: 0.1136 - mean_absolute_percentage_error: 241.1498 - mean_squared_error: 0.1023 - val_loss: 0.1201 - val_mean_absolute_percentage_error: 223.1893 - val_mean_squared_error: 0.1048
# Epoch 6/30
# 36085/36085 [==============================] - 18s 489us/step - loss: 0.1046 - mean_absolute_percentage_error: 220.5370 - mean_squared_error: 0.0952 - val_loss: 0.1036 - val_mean_absolute_percentage_error: 226.7293 - val_mean_squared_error: 0.0995
# Epoch 7/30
# 36085/36085 [==============================] - 18s 503us/step - loss: 0.1011 - mean_absolute_percentage_error: 221.7824 - mean_squared_error: 0.0923 - val_loss: 0.1003 - val_mean_absolute_percentage_error: 208.6695 - val_mean_squared_error: 0.0954
# Epoch 8/30
# 36085/36085 [==============================] - 18s 500us/step - loss: 0.0962 - mean_absolute_percentage_error: 207.0427 - mean_squared_error: 0.0878 - val_loss: 0.0954 - val_mean_absolute_percentage_error: 149.4326 - val_mean_squared_error: 0.0899
# Epoch 9/30
# 36085/36085 [==============================] - 19s 533us/step - loss: 0.0934 - mean_absolute_percentage_error: 198.0569 - mean_squared_error: 0.0853 - val_loss: 0.0899 - val_mean_absolute_percentage_error: 123.4807 - val_mean_squared_error: 0.0843
# Epoch 10/30
# 36085/36085 [==============================] - 20s 547us/step - loss: 0.0846 - mean_absolute_percentage_error: 183.8421 - mean_squared_error: 0.0786 - val_loss: 0.0874 - val_mean_absolute_percentage_error: 109.9699 - val_mean_squared_error: 0.0817
# Epoch 23/30
# 36085/36085 [==============================] - 19s 514us/step - loss: 0.0828 - mean_absolute_percentage_error: 149.3295 - mean_squared_error: 0.0769 - val_loss: 0.0802 - val_mean_absolute_percentage_error: 79.3982 - val_mean_squared_error: 0.0751
# Epoch 24/30
# 36085/36085 [==============================] - 19s 528us/step - loss: 0.0836 - mean_absolute_percentage_error: 157.7440 - mean_squared_error: 0.0778 - val_loss: 0.0872 - val_mean_absolute_percentage_error: 98.4206 - val_mean_squared_error: 0.0795
# Epoch 25/30
# 36085/36085 [==============================] - 18s 512us/step - loss: 0.0821 - mean_absolute_percentage_error: 140.8386 - mean_squared_error: 0.0762 - val_loss: 0.0858 - val_mean_absolute_percentage_error: 105.0846 - val_mean_squared_error: 0.0761
# Epoch 26/30
# 36085/36085 [==============================] - 19s 526us/step - loss: 0.0827 - mean_absolute_percentage_error: 151.2492 - mean_squared_error: 0.0768 - val_loss: 0.0839 - val_mean_absolute_percentage_error: 110.4855 - val_mean_squared_error: 0.0796
# Epoch 27/30
# 36085/36085 [==============================] - 18s 513us/step - loss: 0.0831 - mean_absolute_percentage_error: 164.8232 - mean_squared_error: 0.0771 - val_loss: 0.0837 - val_mean_absolute_percentage_error: 128.5851 - val_mean_squared_error: 0.0804
# Epoch 28/30
# 36085/36085 [==============================] - 20s 560us/step - loss: 0.0812 - mean_absolute_percentage_error: 161.0743 - mean_squared_error: 0.0757 - val_loss: 0.0767 - val_mean_absolute_percentage_error: 73.2272 - val_mean_squared_error: 0.0738
# Epoch 29/30
# 36085/36085 [==============================] - 19s 521us/step - loss: 0.0815 - mean_absolute_percentage_error: 116.8360 - mean_squared_error: 0.0760 - val_loss: 0.0855 - val_mean_absolute_percentage_error: 99.1578 - val_mean_squared_error: 0.0772
# Epoch 30/30
# 36085/36085 [==============================] - 19s 527us/step - loss: 0.0806 - mean_absolute_percentage_error: 158.4958 - mean_squared_error: 0.0753 - val_loss: 0.0888 - val_mean_absolute_percentage_error: 108.1811 - val_mean_squared_error: 0.0786

# %% [markdown]
# ### 3.1 Results
# Take care these results are on scaled parameter values and not rescaled yet!

# %%
def constraint_violation(x):
    return np.sum(x[:,0]*x[:,2]**2+x[:,1]>=1)/x.shape[0],x[:,0]*x[:,2]**2+x[:,1]>=1,x[:,0]*x[:,2]**2+x[:,1]
prediction = NN2.predict(y_test_trafo2)

prediction_invtrafo= np.array([myinverse(x) for x in prediction])

prediction = NN2.predict(y_test_trafo2)
prediction_std = np.std(prediction,axis=0)
error = np.zeros((Ntest,Nparameters))
for i in range(Ntest):
    error[i,:] =  np.abs((X_test_trafo2[i,:]-prediction[i,:])/X_test_trafo2[i,:])
err1 = np.mean(error,axis = 0)
err2 = np.median(error,axis = 0)
err_std = np.std(error,axis = 0)
idx = np.argsort(error[:,0], axis=None)
good_idx = idx[:-100]

plt.figure(figsize=(14,4))
ax=plt.subplot(1,3,1)
plt.boxplot(error)
plt.yscale("log")
plt.xticks([1, 2, 3,4,5], ['w','a','b','g*','h0'])
plt.ylabel("Errors")
plt.show()
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.lines as mlines
import matplotlib.transforms as mtransforms
_,_,c =constraint_violation(prediction_invtrafo)
_,_,c2 =constraint_violation(X_test)


testing_violation = c>=1
testing_violation2 = (c<1)
vio_error = error[testing_violation,:]
vio_error2 = error[testing_violation2,:]
ax=plt.subplot(1,3,2)

plt.boxplot(vio_error)
plt.yscale("log")
plt.xticks([1, 2, 3,4,5], ['w','a','b','g*','h0'])
plt.ylabel("Errors parameter violation")
plt.show()
ax=plt.subplot(1,3,3)

plt.boxplot(vio_error2)
plt.yscale("log")
plt.xticks([1, 2, 3,4,5], ['w','a','b','g*','h0'])
plt.ylabel("Errors no parameter violation")
plt.show()
print("violation error mean in %:",100*np.mean(vio_error,axis=0))
print("no violation error mean in %:",100*np.mean(vio_error2,axis=0))
print("violation error median in %:",100*np.median(vio_error,axis=0))
print("no violation error median in %:",100*np.median(vio_error2,axis=0))
print("error mean in %:",100*err1)
print("error median in %:",100*err2)

fig = plt.figure()
plt.scatter(c2,c)
plt.plot(np.arange(0, np.max(c),0.5),np.arange(0, np.max(c),0.5),'-r')
plt.xlabel("True Constraint")
plt.ylabel("Forecasted Constraint")


plt.figure(figsize=(14,4))
ax=plt.subplot(1,5,1)
plt.yscale("log")
plt.scatter(c2[testing_violation2],vio_error2[:,0],c="r",s=1,marker="x",label="alpha no con")
plt.scatter(c2[testing_violation],vio_error[:,0],c="b",s=1,marker="x",label="alpha con")
plt.xlabel("True Constraint")
plt.ylabel("Relative Deviation")
plt.legend()
ax=plt.subplot(1,5,2)
plt.yscale("log")
plt.scatter(c2[testing_violation2],vio_error2[:,1],c="r",s=1,marker="x",label="beta no con")
plt.scatter(c2[testing_violation],vio_error[:,1],c="b",s=1,marker="x",label="beta con")
plt.xlabel("True Constraint")
plt.ylabel("Relative Deviation")
plt.legend()
ax=plt.subplot(1,5,3)
plt.yscale("log")
plt.scatter(c2[testing_violation2],vio_error2[:,2],c="r",s=1,marker="x",label="gamma no con")
plt.scatter(c2[testing_violation],vio_error[:,2],c="b",s=1,marker="x",label="gamma con")
plt.xlabel("True Constraint")
plt.ylabel("Relative Deviation")
plt.legend()
ax=plt.subplot(1,5,4)
plt.yscale("log")
plt.scatter(c2[testing_violation2],vio_error2[:,3],c="r",s=1,marker="x",label="omega no con")
plt.scatter(c2[testing_violation],vio_error[:,3],c="b",s=1,marker="x",label="omega con")
plt.xlabel("True Constraint")
plt.ylabel("Relative Deviation")
plt.legend()
ax=plt.subplot(1,5,5)
plt.yscale("log")
plt.scatter(c2[testing_violation2],vio_error2[:,4],c="r",s=1,marker="x",label="sigma0 no con")
plt.scatter(c2[testing_violation],vio_error[:,4],c="b",s=1,marker="x",label="sigma0 con")
plt.xlabel("True Constraint")
plt.ylabel("Relative Deviation")
plt.legend()
fig = plt.figure()
plt.scatter(c2,c)
plt.plot(np.arange(0, np.max(c),0.5),np.arange(0, np.max(c),0.5),'-r')
plt.xlabel("True Constraint")
plt.ylabel("Forecasted Constraint")

plt.figure(figsize=(14,4))
ax=plt.subplot(1,5,1)
plt.yscale("log")
plt.xscale("log")
plt.scatter(abs((c2[testing_violation2]-c[testing_violation2])/c2[testing_violation2]),vio_error2[:,0],c="r",s=1,marker="x",label="alpha no con")
plt.scatter(abs((c2[testing_violation]-c[testing_violation])/c2[testing_violation]),vio_error[:,0],c="b",s=1,marker="x",label="alpha con")
plt.xlabel("constraint deviation")
plt.ylabel("Relative Deviation")
plt.legend()
ax=plt.subplot(1,5,2)
plt.yscale("log")
plt.xscale("log")
plt.scatter(abs((c2[testing_violation2]-c[testing_violation2])/c2[testing_violation2]),vio_error2[:,1],c="r",s=1,marker="x",label="beta no con")
plt.scatter(abs((c2[testing_violation]-c[testing_violation])/c2[testing_violation]),vio_error[:,1],c="b",s=1,marker="x",label="beta con")
plt.xlabel("constraint deviation")
plt.ylabel("Relative Deviation")
plt.legend()
ax=plt.subplot(1,5,3)
plt.yscale("log")
plt.xscale("log")
plt.scatter(abs((c2[testing_violation2]-c[testing_violation2])/c2[testing_violation2]),vio_error2[:,2],c="r",s=1,marker="x",label="gamma no con")
plt.scatter(abs((c2[testing_violation]-c[testing_violation])/c2[testing_violation]),vio_error[:,2],c="b",s=1,marker="x",label="gamma con")
plt.xlabel("constraint deviation")
plt.ylabel("Relative Deviation")
plt.legend()
ax=plt.subplot(1,5,4)
plt.yscale("log")
plt.xscale("log")
plt.scatter(abs((c2[testing_violation2]-c[testing_violation2])/c2[testing_violation2]),vio_error2[:,3],c="r",s=1,marker="x",label="omega no con")
plt.scatter(abs((c2[testing_violation]-c[testing_violation])/c2[testing_violation]),vio_error[:,3],c="b",s=1,marker="x",label="omega con")
plt.xlabel("constraint deviation")
plt.ylabel("Relative Deviation")
plt.legend()
ax=plt.subplot(1,5,5)
plt.yscale("log")
plt.xscale("log")
plt.scatter(abs((c2[testing_violation2]-c[testing_violation2])/c2[testing_violation2]),vio_error2[:,4],c="r",s=1,marker="x",label="sigma0 no con")
plt.scatter(abs((c2[testing_violation]-c[testing_violation])/c2[testing_violation]),vio_error[:,4],c="b",s=1,marker="x",label="sigma0 con")
plt.xlabel("constraint deviation")
plt.ylabel("Relative Deviation")
plt.legend()
# Out:
# violation error mean in %: [ 44.17845613  82.80603969  58.40149005 101.3447939   64.42370048]
# no violation error mean in %: [ 56.1098164  150.43436535  27.1028299  132.71449098  51.42100292]
# violation error median in %: [ 13.69263171  14.80141187  21.81485481 100.1016536   20.9370306 ]
# no violation error median in %: [ 12.97769453  20.37536441   4.47813556 100.19861708  10.58601226]
# error mean in %: [ 55.58912311 147.48301576  28.46872632 131.34549446  51.98845015]
# error median in %: [ 13.01564889  20.05570431   4.6528458  100.19439572  10.88798772]

# %% [markdown]
# # 3.1 No parameter constraint

# %%
NN2a = Sequential() 
NN2a.add(InputLayer(input_shape=(Nmaturities,Nstrikes,1)))
NN2a.add(Conv2D(64,(3, 3),use_bias= True, padding='valid',strides =(1,1),activation ='tanh'))
NN2a.add(Conv2D(64,(2, 2),use_bias= True,padding='valid',strides =(1,1),activation ='tanh'))
NN2a.add(MaxPooling2D(pool_size=(2, 2)))
NN2a.add(Conv2D(64,(2, 2),use_bias= True,padding='valid',strides =(1,1),activation ='tanh'))
NN2a.add(ZeroPadding2D(padding=(1,1)))
NN2a.add(Conv2D(64,(2, 2),use_bias= True,padding='valid',strides =(1,1),activation ='tanh'))
NN2a.add(ZeroPadding2D(padding=(1,1)))
NN2a.add(Conv2D(64,(2, 2),use_bias= True,padding='valid',strides =(1,1),activation ='tanh'))
NN2a.add(Conv2D(64,(2, 2),use_bias= True,padding='valid',strides =(1,1),activation ='tanh'))
NN2a.add(ZeroPadding2D(padding=(1,1)))
NN2a.add(Conv2D(64,(2, 2),use_bias= True,padding='valid',strides =(1,1),activation ='tanh'))
NN2a.add(ZeroPadding2D(padding=(1,1)))
NN2a.add(Conv2D(64,(2, 2),use_bias= True,padding='valid',strides =(1,1),activation ='tanh'))
NN2a.add(Flatten())
NN2a.add(Dense(5,activation = 'linear',use_bias=True))
NN2a.summary()


NN2a.compile(loss = "MSE", optimizer = "adam",metrics=["MAPE","MSE"])
#NN2.compile(loss =mse_constraint(0.25), optimizer = "adam",metrics=["MAPE", "MSE"])
#NN2.fit(y_train_trafo2,X_train_trafo2, batch_size=50, validation_data = (y_val_trafo2,X_val_trafo2),
#        epochs = 50, verbose = True, shuffle=1)
history = NN2a.fit(y_train_trafo2,X_train_trafo2, batch_size=50, validation_data = (y_val_trafo2,X_val_trafo2),
    epochs=30, verbose = True, shuffle=1)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_17 (Conv2D)           (None, 5, 7, 64)          640
# _________________________________________________________________
# conv2d_18 (Conv2D)           (None, 4, 6, 64)          16448
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 2, 3, 64)          0
# _________________________________________________________________
# conv2d_19 (Conv2D)           (None, 1, 2, 64)          16448
# _________________________________________________________________
# zero_padding2d_9 (ZeroPaddin (None, 3, 4, 64)          0
# _________________________________________________________________
# conv2d_20 (Conv2D)           (None, 2, 3, 64)          16448
# _________________________________________________________________
# zero_padding2d_10 (ZeroPaddi (None, 4, 5, 64)          0
# _________________________________________________________________
# conv2d_21 (Conv2D)           (None, 3, 4, 64)          16448
# _________________________________________________________________
# conv2d_22 (Conv2D)           (None, 2, 3, 64)          16448
# _________________________________________________________________
# zero_padding2d_11 (ZeroPaddi (None, 4, 5, 64)          0
# _________________________________________________________________
# conv2d_23 (Conv2D)           (None, 3, 4, 64)          16448
# _________________________________________________________________
# zero_padding2d_12 (ZeroPaddi (None, 5, 6, 64)          0
# _________________________________________________________________
# conv2d_24 (Conv2D)           (None, 4, 5, 64)          16448
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 1280)              0
# _________________________________________________________________
# dense_3 (Dense)              (None, 5)                 6405
# =================================================================
# Total params: 122,181
# Trainable params: 122,181
# Non-trainable params: 0
# _________________________________________________________________
# Train on 36085 samples, validate on 6369 samples
# Epoch 1/30
# 36085/36085 [==============================] - 23s 642us/step - loss: 0.1974 - mean_absolute_percentage_error: 226.9993 - mean_squared_error: 0.1974 - val_loss: 0.1557 - val_mean_absolute_percentage_error: 283.3173 - val_mean_squared_error: 0.1557
# Epoch 2/30
# 36085/36085 [==============================] - 21s 575us/step - loss: 0.1293 - mean_absolute_percentage_error: 224.2891 - mean_squared_error: 0.1293 - val_loss: 0.1205 - val_mean_absolute_percentage_error: 261.3010 - val_mean_squared_error: 0.1205
# Epoch 3/30
# 36085/36085 [==============================] - 21s 587us/step - loss: 0.1157 - mean_absolute_percentage_error: 245.9489 - mean_squared_error: 0.1157 - val_loss: 0.1085 - val_mean_absolute_percentage_error: 210.2857 - val_mean_squared_error: 0.1085 loss: 0.1162 - mean_absolute_percentage_error: 2
# Epoch 4/30
# Epoch 29/30
# 36085/36085 [==============================] - 19s 518us/step - loss: 0.0756 - mean_absolute_percentage_error: 161.5623 - mean_squared_error: 0.0756 - val_loss: 0.0754 - val_mean_absolute_percentage_error: 82.6135 - val_mean_squared_error: 0.0754
# Epoch 30/30
# 36085/36085 [==============================] - 19s 521us/step - loss: 0.0762 - mean_absolute_percentage_error: 133.6802 - mean_squared_error: 0.0762 - val_loss: 0.0788 - val_mean_absolute_percentage_error: 138.9773 - val_mean_squared_error: 0.0788

# %%
prediction = NN2a.predict(y_test_trafo2)

prediction_invtrafo= np.array([myinverse(x) for x in prediction])

prediction = NN2a.predict(y_test_trafo2)
prediction_std = np.std(prediction,axis=0)
error = np.zeros((Ntest,Nparameters))
for i in range(Ntest):
    error[i,:] =  np.abs((X_test_trafo2[i,:]-prediction[i,:])/X_test_trafo2[i,:])
err1 = np.mean(error,axis = 0)
err2 = np.median(error,axis = 0)
err_std = np.std(error,axis = 0)
idx = np.argsort(error[:,0], axis=None)
good_idx = idx[:-100]

plt.figure(figsize=(14,4))
ax=plt.subplot(1,3,1)
plt.boxplot(error)
plt.yscale("log")
plt.xticks([1, 2, 3,4,5], ['w','a','b','g*','h0'])
plt.ylabel("Errors")
plt.show()
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.lines as mlines
import matplotlib.transforms as mtransforms
_,_,c =constraint_violation(prediction_invtrafo)
_,_,c2 =constraint_violation(X_test)


testing_violation = c>=1
testing_violation2 = (c<1)
vio_error = error[testing_violation,:]
vio_error2 = error[testing_violation2,:]
ax=plt.subplot(1,3,2)

plt.boxplot(vio_error)
plt.yscale("log")
plt.xticks([1, 2, 3,4,5], ['w','a','b','g*','h0'])
plt.ylabel("Errors parameter violation")
plt.show()
ax=plt.subplot(1,3,3)

plt.boxplot(vio_error2)
plt.yscale("log")
plt.xticks([1, 2, 3,4,5], ['w','a','b','g*','h0'])
plt.ylabel("Errors no parameter violation")
plt.show()
print("error mean in %:",100*err1)
print("error median in %:",100*err2)
print("violation error mean in %:",100*np.mean(vio_error,axis=0))
print("no violation error mean in %:",100*np.mean(vio_error2,axis=0))
print("violation error median in %:",100*np.median(vio_error,axis=0))
print("no violation error median in %:",100*np.median(vio_error2,axis=0))


fig = plt.figure()
plt.scatter(c2,c)
plt.plot(np.arange(0, np.max(c),0.5),np.arange(0, np.max(c),0.5),'-r')
plt.xlabel("True Constraint")
plt.ylabel("Forecasted Constraint")


plt.figure(figsize=(14,4))
ax=plt.subplot(1,5,1)
plt.yscale("log")
plt.scatter(c2[testing_violation2],vio_error2[:,0],c="r",s=1,marker="x",label="alpha no con")
plt.scatter(c2[testing_violation],vio_error[:,0],c="b",s=1,marker="x",label="alpha con")
plt.xlabel("True Constraint")
plt.ylabel("Relative Deviation")
plt.legend()
ax=plt.subplot(1,5,2)
plt.yscale("log")
plt.scatter(c2[testing_violation2],vio_error2[:,1],c="r",s=1,marker="x",label="beta no con")
plt.scatter(c2[testing_violation],vio_error[:,1],c="b",s=1,marker="x",label="beta con")
plt.xlabel("True Constraint")
plt.ylabel("Relative Deviation")
plt.legend()
ax=plt.subplot(1,5,3)
plt.yscale("log")
plt.scatter(c2[testing_violation2],vio_error2[:,2],c="r",s=1,marker="x",label="gamma no con")
plt.scatter(c2[testing_violation],vio_error[:,2],c="b",s=1,marker="x",label="gamma con")
plt.xlabel("True Constraint")
plt.ylabel("Relative Deviation")
plt.legend()
ax=plt.subplot(1,5,4)
plt.yscale("log")
plt.scatter(c2[testing_violation2],vio_error2[:,3],c="r",s=1,marker="x",label="omega no con")
plt.scatter(c2[testing_violation],vio_error[:,3],c="b",s=1,marker="x",label="omega con")
plt.xlabel("True Constraint")
plt.ylabel("Relative Deviation")
plt.legend()
ax=plt.subplot(1,5,5)
plt.yscale("log")
plt.scatter(c2[testing_violation2],vio_error2[:,4],c="r",s=1,marker="x",label="sigma0 no con")
plt.scatter(c2[testing_violation],vio_error[:,4],c="b",s=1,marker="x",label="sigma0 con")
plt.xlabel("True Constraint")
plt.ylabel("Relative Deviation")
plt.legend()
fig = plt.figure()
plt.scatter(c2,c)
plt.plot(np.arange(0, np.max(c),0.5),np.arange(0, np.max(c),0.5),'-r')
plt.xlabel("True Constraint")
plt.ylabel("Forecasted Constraint")

plt.figure(figsize=(14,4))
ax=plt.subplot(1,5,1)
plt.yscale("log")
plt.xscale("log")
plt.scatter(abs((c2[testing_violation2]-c[testing_violation2])/c2[testing_violation2]),vio_error2[:,0],c="r",s=1,marker="x",label="alpha no con")
plt.scatter(abs((c2[testing_violation]-c[testing_violation])/c2[testing_violation]),vio_error[:,0],c="b",s=1,marker="x",label="alpha con")
plt.xlabel("constraint deviation")
plt.ylabel("Relative Deviation")
plt.legend()
ax=plt.subplot(1,5,2)
plt.yscale("log")
plt.xscale("log")
plt.scatter(abs((c2[testing_violation2]-c[testing_violation2])/c2[testing_violation2]),vio_error2[:,1],c="r",s=1,marker="x",label="beta no con")
plt.scatter(abs((c2[testing_violation]-c[testing_violation])/c2[testing_violation]),vio_error[:,1],c="b",s=1,marker="x",label="beta con")
plt.xlabel("constraint deviation")
plt.ylabel("Relative Deviation")
plt.legend()
ax=plt.subplot(1,5,3)
plt.yscale("log")
plt.xscale("log")
plt.scatter(abs((c2[testing_violation2]-c[testing_violation2])/c2[testing_violation2]),vio_error2[:,2],c="r",s=1,marker="x",label="gamma no con")
plt.scatter(abs((c2[testing_violation]-c[testing_violation])/c2[testing_violation]),vio_error[:,2],c="b",s=1,marker="x",label="gamma con")
plt.xlabel("constraint deviation")
plt.ylabel("Relative Deviation")
plt.legend()
ax=plt.subplot(1,5,4)
plt.yscale("log")
plt.xscale("log")
plt.scatter(abs((c2[testing_violation2]-c[testing_violation2])/c2[testing_violation2]),vio_error2[:,3],c="r",s=1,marker="x",label="omega no con")
plt.scatter(abs((c2[testing_violation]-c[testing_violation])/c2[testing_violation]),vio_error[:,3],c="b",s=1,marker="x",label="omega con")
plt.xlabel("constraint deviation")
plt.ylabel("Relative Deviation")
plt.legend()
ax=plt.subplot(1,5,5)
plt.yscale("log")
plt.xscale("log")
plt.scatter(abs((c2[testing_violation2]-c[testing_violation2])/c2[testing_violation2]),vio_error2[:,4],c="r",s=1,marker="x",label="sigma0 no con")
plt.scatter(abs((c2[testing_violation]-c[testing_violation])/c2[testing_violation]),vio_error[:,4],c="b",s=1,marker="x",label="sigma0 con")
plt.xlabel("constraint deviation")
plt.ylabel("Relative Deviation")
plt.legend()
# Out:
# error mean in %: [ 74.84010156 170.30890246  38.97753968 167.92324819  57.65130082]
# error median in %: [ 10.92677279  20.30837368   4.31454629 101.60299203  12.71430216]
# violation error mean in %: [ 35.7121003   30.1044984   58.32333013 123.01361995  65.84777229]
# no violation error mean in %: [ 75.27837742 171.87934315  38.76084594 168.42628451  57.55949149]
# violation error median in %: [ 13.72955323  13.24308948  11.38560565 104.27226365  18.17412101]
# no violation error median in %: [ 10.89673016  20.53732922   4.27351034 101.59238807  12.66859849]

# %% [markdown]
# # 4. Testing the performace of the AutoEncoder/Decoder Combination
# We test how the two previously trained NN work together. First, HNG-Vola surfaces are used to predict the underlying parameters with NN2. Those predictions are fed into NN1 to get Vola-Surface again. The results are shown below.

# %%
prediction_trafo = prediction.reshape((Ntest,Nparameters,1,1))
forecast = NN1.predict(prediction_trafo).reshape(Ntest,Nmaturities,Nstrikes)
y_true_test = y_test_trafo2.reshape(Ntest,Nmaturities,Nstrikes)
# Example Plots
X = strikes
Y = maturities
X, Y = np.meshgrid(X, Y)
from mpl_toolkits.mplot3d import Axes3D  
from matplotlib import cm
import random
sample_idx = random.randint(0,len(y_test))
fig = plt.figure()
ax = fig.gca(projection='3d')
#ax.contour3D(X, Y, Z, 50, cmap='binary')
ax.plot_surface(X, Y, y_true_test[sample_idx,:,:], rstride=1, cstride=1,
                cmap='viridis', edgecolor='none')
ax.plot_surface(X, Y, forecast[sample_idx,:,:] , rstride=1, cstride=1,
                cmap='viridis', edgecolor='none')
ax.set_xlabel('Strikes')
ax.set_ylabel('Maturities')
plt.show()
#error plots
mape = np.zeros(forecast.shape)
mse  = np.zeros(forecast.shape)
for i in range(Ntest):
    mape[i,:,:] =  np.abs((y_true_test[i,:,:]-forecast[i,:,:])/y_true_test[i,:,:])
    mse[i,:,:]  =  np.square((y_true_test[i,:,:]-forecast[i,:,:]))
idx = np.argsort(np.max(err_rel_mat,axis=tuple([1,2])), axis=None)

#bad_idx = idx[:-200]
bad_idx = idx
#from matplotlib.colors import LogNorm
plt.figure(figsize=(14,4))
ax=plt.subplot(2,3,1)
err1 = 100*np.mean(mape[bad_idx,:,:],axis=0)
plt.title("Average relative error",fontsize=15,y=1.04)
plt.imshow(err1)#,norm=LogNorm(vmin=err1.min(), vmax=err1.max()))
plt.setp(ax.get_xticklabels(), rotation=30, horizontalalignment='right')
plt.colorbar(format=mtick.PercentFormatter())
ax.set_xticks(np.linspace(0,Nstrikes-1,Nstrikes))
ax.set_xticklabels(strikes)
ax.set_yticks(np.linspace(0,Nmaturities-1,Nmaturities))
ax.set_yticklabels(maturities)
plt.xlabel("Strike",fontsize=15,labelpad=5)
plt.ylabel("Maturity",fontsize=15,labelpad=5)
ax=plt.subplot(2,3,2)
err2 = 100*np.std(mape[bad_idx,:,:],axis = 0)
plt.title("Std relative error",fontsize=15,y=1.04)
plt.imshow(err2)#,norm=LogNorm(vmin=err2.min(), vmax=err2.max()))
plt.colorbar(format=mtick.PercentFormatter())
plt.setp(ax.get_xticklabels(), rotation=30, horizontalalignment='right')
ax.set_xticks(np.linspace(0,Nstrikes-1,Nstrikes))
ax.set_xticklabels(strikes)
ax.set_yticks(np.linspace(0,Nmaturities-1,Nmaturities))
ax.set_yticklabels(maturities)
plt.xlabel("Strike",fontsize=15,labelpad=5)
plt.ylabel("Maturity",fontsize=15,labelpad=5)
ax=plt.subplot(2,3,3)
err3 = 100*np.max(mape[bad_idx,:,:],axis = 0)
plt.title("Maximum relative error",fontsize=15,y=1.04)
plt.imshow(err3)#,norm=LogNorm(vmin=err3.min(), vmax=err3.max()))
plt.colorbar(format=mtick.PercentFormatter())
plt.setp(ax.get_xticklabels(), rotation=30, horizontalalignment='right')
ax.set_xticks(np.linspace(0,Nstrikes-1,Nstrikes))
ax.set_xticklabels(strikes)
ax.set_yticks(np.linspace(0,Nmaturities-1,Nmaturities))
ax.set_yticklabels(maturities)
plt.xlabel("Strike",fontsize=15,labelpad=5)
plt.ylabel("Maturity",fontsize=15,labelpad=5)
ax=plt.subplot(2,3,4)
err1 = np.sqrt(np.mean(mse[bad_idx,:,:],axis=0))
plt.title("RMSE",fontsize=15,y=1.04)
plt.imshow(err1)#,norm=LogNorm(vmin=err1.min(), vmax=err1.max()))
plt.colorbar(format=mtick.PercentFormatter())
plt.setp(ax.get_xticklabels(), rotation=30, horizontalalignment='right')
ax.set_xticks(np.linspace(0,Nstrikes-1,Nstrikes))
ax.set_xticklabels(strikes)
ax.set_yticks(np.linspace(0,Nmaturities-1,Nmaturities))
ax.set_yticklabels(maturities)
plt.xlabel("Strike",fontsize=15,labelpad=5)
plt.ylabel("Maturity",fontsize=15,labelpad=5)
ax=plt.subplot(2,3,5)
err2 = np.std(mse[bad_idx,:,:],axis = 0)
plt.title("Std MSE",fontsize=15,y=1.04)
plt.imshow(err2)#,norm=LogNorm(vmin=err2.min(), vmax=err2.max()))
plt.colorbar(format=mtick.PercentFormatter())
plt.setp(ax.get_xticklabels(), rotation=30, horizontalalignment='right')
ax.set_xticks(np.linspace(0,Nstrikes-1,Nstrikes))
ax.set_xticklabels(strikes)
ax.set_yticks(np.linspace(0,Nmaturities-1,Nmaturities))
ax.set_yticklabels(maturities)
plt.xlabel("Strike",fontsize=15,labelpad=5)
plt.ylabel("Maturity",fontsize=15,labelpad=5)
ax=plt.subplot(2,3,6)
err3 = np.max(mse[bad_idx,:,:],axis = 0)
plt.title("Maximum MSE",fontsize=15,y=1.04)
plt.imshow(err3)#,norm=LogNorm(vmin=err3.min(), vmax=err3.max()))
plt.colorbar(format=mtick.PercentFormatter())
ax.set_xticks(np.linspace(0,Nstrikes-1,Nstrikes))
ax.set_xticklabels(strikes)
ax.set_yticks(np.linspace(0,Nmaturities-1,Nmaturities))
ax.set_yticklabels(maturities)
plt.xlabel("Strike",fontsize=15,labelpad=5)
plt.ylabel("Maturity",fontsize=15,labelpad=5)
plt.setp(ax.get_xticklabels(), rotation=30, horizontalalignment='right')
plt.tight_layout()
plt.show()

# %% [markdown]
# # 5. FFNN as Encoder / Pricing Kernel - Approach of Horvath (improved)

# %%
X_test_trafo3  = X_test_trafo.reshape((Ntest,5))
X_train_trafo3 = X_train_trafo.reshape((Ntrain,5))
X_val_trafo3   = X_val_trafo.reshape((Nval,5))
#Neural Network
keras.backend.set_floatx('float64')
NN3 = Sequential()
NN3.add(InputLayer(input_shape=(Nparameters,)))
NN3.add(Dense(30, activation = 'elu'))
NN3.add(Dense(30, activation = 'elu'))
#NN3.add(Dropout(0.05))
NN3.add(Dense(30, activation = 'relu'))
NN3.add(Dense(Nstrikes*Nmaturities, activation = 'linear', use_bias=True,kernel_constraint = keras.constraints.NonNeg()))
NN3.summary()
"""
#Neural Network Horvath
NN4 = Sequential()
NN4.add(InputLayer(input_shape=(Nparameters,)))
NN4.add(Dense(30, activation = 'elu'))
NN4.add(Dense(30, activation = 'elu'))
NN4.add(Dense(30, activation = 'elu'))
NN4.add(Dense(Nstrikes*Nmaturities, activation = 'linear'))
NN4.summary()
"""               
NN3.compile(loss = root_relative_mean_squared_error, optimizer = "adam",metrics=["MSE","MAPE"])
#NN3.compile(loss = "mean_squared_error", optimizer = "adam",metrics=["MAPE"])
#NN3.compile(loss = root_relative_mean_squared_error, optimizer = "adam",metrics=["MAPE","mean_squared_error"])
#NN3.compile(loss = 'mean_absolute_percentage_error', optimizer = "adam")
NN3.fit(X_train_trafo3, y_train, batch_size=32, validation_data = (X_val_trafo3, y_val),
        epochs = 200, verbose = True, shuffle=1)
#NN4.compile(loss = root_relative_mean_squared_error, optimizer = "adam",metrics=["MSE"])
#NN4.compile(loss = "mean_squared_error", optimizer = "adam",metrics=["MAPE"])
#NN4.compile(loss = root_relative_mean_squared_error, optimizer = "adam",metrics=["MAPE","mean_squared_error"])
#NN4.compile(loss = 'mean_absolute_percentage_error', optimizer = "adam")
#NN4.fit(X_train_trafo3, y_train, batch_size=32, validation_data = (X_val_trafo3, y_val),
#       epochs = 200, verbose = True, shuffle=1)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_60 (Dense)             (None, 30)                180
# _________________________________________________________________
# dense_61 (Dense)             (None, 30)                930
# _________________________________________________________________
# dense_62 (Dense)             (None, 30)                930
# _________________________________________________________________
# dense_63 (Dense)             (None, 63)                1953
# =================================================================
# Total params: 3,993
# Trainable params: 3,993
# Non-trainable params: 0
# _________________________________________________________________
# Train on 36085 samples, validate on 6369 samples
# Epoch 1/200
# 36085/36085 [==============================] - 3s 92us/step - loss: 0.5255 - mean_squared_error: 0.0112 - val_loss: 0.4980 - val_mean_squared_error: 0.0109
# Epoch 2/200
# 36085/36085 [==============================] - 1s 39us/step - loss: 0.4938 - mean_squared_error: 0.0109 - val_loss: 0.4974 - val_mean_squared_error: 0.0107
# Epoch 3/200
# 36085/36085 [==============================] - 2s 43us/step - loss: 0.4925 - mean_squared_error: 0.0108 - val_loss: 0.4975 - val_mean_squared_error: 0.0115
# Epoch 4/200
# 36085/36085 [==============================] - 2s 42us/step - loss: 0.4916 - mean_squared_error: 0.0108 - val_loss: 0.4956 - val_mean_squared_error: 0.0112
# Epoch 5/200
# 36085/36085 [==============================] - 1s 41us/step - loss: 0.4917 - mean_squared_error: 0.0108 - val_loss: 0.4952 - val_mean_squared_error: 0.0111
# Epoch 6/200
# 36085/36085 [==============================] - 1s 40us/step - loss: 0.4915 - mean_squared_error: 0.0108 - val_loss: 0.4952 - val_mean_squared_error: 0.0110
# Epoch 7/200
# 36085/36085 [==============================] - 1s 40us/step - loss: 0.4911 - mean_squared_error: 0.0108 - val_loss: 0.4952 - val_mean_squared_error: 0.0111
# Epoch 8/200
# 36085/36085 [==============================] - 1s 39us/step - loss: 0.4914 - mean_squared_error: 0.0108 - val_loss: 0.4984 - val_mean_squared_error: 0.0104
# Epoch 9/200
# 36085/36085 [==============================] - 1s 39us/step - loss: 0.4915 - mean_squared_error: 0.0108 - val_loss: 0.4953 - val_mean_squared_error: 0.0111
# Epoch 10/200
# 36085/36085 [==============================] - 1s 39us/step - loss: 0.4911 - mean_squared_error: 0.0108 - val_loss: 0.4956 - val_mean_squared_error: 0.0107
# Epoch 11/200
# 36085/36085 [==============================] - 1s 39us/step - loss: 0.4913 - mean_squared_error: 0.0108 - val_loss: 0.4955 - val_mean_squared_error: 0.0108
# Epoch 12/200
# 36085/36085 [==============================] - 2s 46us/step - loss: 0.4916 - mean_squared_error: 0.0108 - val_loss: 0.4953 - val_mean_squared_error: 0.0111
# Epoch 13/200
# 36085/36085 [==============================] - 1s 41us/step - loss: 0.4913 - mean_squared_error: 0.0108 - val_loss: 0.4954 - val_mean_squared_error: 0.0111
# Epoch 14/200
# 36085/36085 [==============================] - 1s 41us/step - loss: 0.4913 - mean_squared_error: 0.0108 - val_loss: 0.4953 - val_mean_squared_error: 0.0109
# Epoch 15/200
# 36085/36085 [==============================] - 2s 42us/step - loss: 0.4915 - mean_squared_error: 0.0108 - val_loss: 0.4959 - val_mean_squared_error: 0.0107
# Epoch 16/200
# 36085/36085 [==============================] - 1s 40us/step - loss: 0.4909 - mean_squared_error: 0.0108 - val_loss: 0.4973 - val_mean_squared_error: 0.0105
# Epoch 17/200
# 36085/36085 [==============================] - 1s 39us/step - loss: 0.4916 - mean_squared_error: 0.0108 - val_loss: 0.4952 - val_mean_squared_error: 0.0110
# Epoch 18/200
# 36085/36085 [==============================] - 2s 43us/step - loss: 0.4914 - mean_squared_error: 0.0108 - val_loss: 0.4958 - val_mean_squared_error: 0.0112
# Epoch 19/200
# 36085/36085 [==============================] - 2s 42us/step - loss: 0.4914 - mean_squared_error: 0.0109 - val_loss: 0.4952 - val_mean_squared_error: 0.0110
# Epoch 20/200
# 36085/36085 [==============================] - 1s 41us/step - loss: 0.4914 - mean_squared_error: 0.0108 - val_loss: 0.4954 - val_mean_squared_error: 0.0111
# Epoch 21/200
# 36085/36085 [==============================] - 1s 39us/step - loss: 0.4913 - mean_squared_error: 0.0108 - val_loss: 0.4953 - val_mean_squared_error: 0.0111
# Epoch 22/200
# 36085/36085 [==============================] - 2s 43us/step - loss: 0.4913 - mean_squared_error: 0.0108 - val_loss: 0.4952 - val_mean_squared_error: 0.0109
# Epoch 23/200
# 36085/36085 [==============================] - 1s 39us/step - loss: 0.4910 - mean_squared_error: 0.0108 - val_loss: 0.4955 - val_mean_squared_error: 0.0112
# Epoch 24/200
# 36085/36085 [==============================] - 1s 41us/step - loss: 0.4914 - mean_squared_error: 0.0108 - val_loss: 0.4952 - val_mean_squared_error: 0.0110
# Epoch 25/200
# 36085/36085 [==============================] - 1s 41us/step - loss: 0.4914 - mean_squared_error: 0.0108 - val_loss: 0.4952 - val_mean_squared_error: 0.0110
# Epoch 26/200
# 36085/36085 [==============================] - 1s 39us/step - loss: 0.4912 - mean_squared_error: 0.0108 - val_loss: 0.4962 - val_mean_squared_error: 0.0106
# Epoch 27/200
# 36085/36085 [==============================] - 1s 39us/step - loss: 0.4915 - mean_squared_error: 0.0108 - val_loss: 0.4952 - val_mean_squared_error: 0.0110
# Epoch 28/200
# 36085/36085 [==============================] - 1s 39us/step - loss: 0.4913 - mean_squared_error: 0.0108 - val_loss: 0.4973 - val_mean_squared_error: 0.0115
# Epoch 29/200
# 36085/36085 [==============================] - 1s 40us/step - loss: 0.4917 - mean_squared_error: 0.0108 - val_loss: 0.4955 - val_mean_squared_error: 0.0108
# Epoch 30/200
# 36085/36085 [==============================] - 2s 48us/step - loss: 0.4916 - mean_squared_error: 0.0108 - val_loss: 0.4952 - val_mean_squared_error: 0.0110
# Epoch 31/200
# 36085/36085 [==============================] - 1s 41us/step - loss: 0.4912 - mean_squared_error: 0.0108 - val_loss: 0.4966 - val_mean_squared_error: 0.0106
# Epoch 32/200
# 36085/36085 [==============================] - 1s 39us/step - loss: 0.4913 - mean_squared_error: 0.0108 - val_loss: 0.4958 - val_mean_squared_error: 0.0107
# Epoch 33/200
# 36085/36085 [==============================] - 1s 40us/step - loss: 0.4915 - mean_squared_error: 0.0108 - val_loss: 0.4955 - val_mean_squared_error: 0.0108
# Epoch 34/200
# 36085/36085 [==============================] - 1s 39us/step - loss: 0.4914 - mean_squared_error: 0.0108 - val_loss: 0.4953 - val_mean_squared_error: 0.0109
# Epoch 35/200
# 36085/36085 [==============================] - 1s 40us/step - loss: 0.4914 - mean_squared_error: 0.0108 - val_loss: 0.4954 - val_mean_squared_error: 0.0111
# Epoch 36/200
# 36085/36085 [==============================] - 1s 39us/step - loss: 0.4913 - mean_squared_error: 0.0108 - val_loss: 0.4954 - val_mean_squared_error: 0.0108
# Epoch 37/200
# 36085/36085 [==============================] - 2s 49us/step - loss: 0.4916 - mean_squared_error: 0.0108 - val_loss: 0.4952 - val_mean_squared_error: 0.0110
# Epoch 38/200
# 36085/36085 [==============================] - 2s 44us/step - loss: 0.4913 - mean_squared_error: 0.0108 - val_loss: 0.4957 - val_mean_squared_error: 0.0107
# Epoch 39/200
# 36085/36085 [==============================] - 2s 44us/step - loss: 0.4915 - mean_squared_error: 0.0108 - val_loss: 0.4952 - val_mean_squared_error: 0.0110
# Epoch 40/200
# 36085/36085 [==============================] - 2s 42us/step - loss: 0.4912 - mean_squared_error: 0.0108 - val_loss: 0.4953 - val_mean_squared_error: 0.0111
# Epoch 41/200
# 36085/36085 [==============================] - 1s 41us/step - loss: 0.4914 - mean_squared_error: 0.0109 - val_loss: 0.4952 - val_mean_squared_error: 0.0109
# Epoch 42/200
# 36085/36085 [==============================] - 2s 44us/step - loss: 0.4915 - mean_squared_error: 0.0108 - val_loss: 0.4966 - val_mean_squared_error: 0.0114
# Epoch 43/200
# 36085/36085 [==============================] - 2s 46us/step - loss: 0.4914 - mean_squared_error: 0.0108 - val_loss: 0.4952 - val_mean_squared_error: 0.0110
# Epoch 44/200
# 36085/36085 [==============================] - 2s 42us/step - loss: 0.4913 - mean_squared_error: 0.0108 - val_loss: 0.4952 - val_mean_squared_error: 0.0110
# Epoch 45/200
# 36085/36085 [==============================] - 2s 54us/step - loss: 0.4913 - mean_squared_error: 0.0108 - val_loss: 0.4961 - val_mean_squared_error: 0.0107
# Epoch 46/200
# 36085/36085 [==============================] - 2s 51us/step - loss: 0.4912 - mean_squared_error: 0.0108 - val_loss: 0.4959 - val_mean_squared_error: 0.0107
# Epoch 47/200
# 36085/36085 [==============================] - 2s 53us/step - loss: 0.4915 - mean_squared_error: 0.0108 - val_loss: 0.4952 - val_mean_squared_error: 0.0109
# Epoch 48/200
# 36085/36085 [==============================] - 2s 49us/step - loss: 0.4914 - mean_squared_error: 0.0108 - val_loss: 0.4954 - val_mean_squared_error: 0.0111
# Epoch 49/200
# 36085/36085 [==============================] - 2s 51us/step - loss: 0.4914 - mean_squared_error: 0.0108 - val_loss: 0.4966 - val_mean_squared_error: 0.0106
# Epoch 50/200
# 36085/36085 [==============================] - 2s 49us/step - loss: 0.4914 - mean_squared_error: 0.0108 - val_loss: 0.4957 - val_mean_squared_error: 0.0112
# Epoch 51/200
# 36085/36085 [==============================] - 4s 116us/step - loss: 0.4914 - mean_squared_error: 0.0108 - val_loss: 0.4953 - val_mean_squared_error: 0.0108
# Epoch 52/200
# 36085/36085 [==============================] - 5s 140us/step - loss: 0.4915 - mean_squared_error: 0.0108 - val_loss: 0.4963 - val_mean_squared_error: 0.0113
# Epoch 53/200
# 36085/36085 [==============================] - 2s 52us/step - loss: 0.4914 - mean_squared_error: 0.0108 - val_loss: 0.4960 - val_mean_squared_error: 0.0113
# Epoch 54/200
# 36085/36085 [==============================] - 2s 52us/step - loss: 0.4915 - mean_squared_error: 0.0108 - val_loss: 0.4962 - val_mean_squared_error: 0.0113
# Epoch 55/200
# 36085/36085 [==============================] - 2s 51us/step - loss: 0.4911 - mean_squared_error: 0.0108 - val_loss: 0.4952 - val_mean_squared_error: 0.0110
# Epoch 56/200
# 36085/36085 [==============================] - 2s 48us/step - loss: 0.4915 - mean_squared_error: 0.0108 - val_loss: 0.4959 - val_mean_squared_error: 0.0107
# Epoch 57/200
# 36085/36085 [==============================] - 2s 51us/step - loss: 0.4915 - mean_squared_error: 0.0108 - val_loss: 0.4964 - val_mean_squared_error: 0.0113
# Epoch 58/200
# 36085/36085 [==============================] - 2s 47us/step - loss: 0.4914 - mean_squared_error: 0.0108 - val_loss: 0.4952 - val_mean_squared_error: 0.0109
# Epoch 59/200
# 36085/36085 [==============================] - 2s 51us/step - loss: 0.4912 - mean_squared_error: 0.0108 - val_loss: 0.4952 - val_mean_squared_error: 0.0110
# Epoch 60/200
# 36085/36085 [==============================] - 2s 50us/step - loss: 0.4913 - mean_squared_error: 0.0108 - val_loss: 0.4991 - val_mean_squared_error: 0.0117
# Epoch 61/200
# 36085/36085 [==============================] - 2s 45us/step - loss: 0.4914 - mean_squared_error: 0.0108 - val_loss: 0.4956 - val_mean_squared_error: 0.0108
# Epoch 62/200
# 36085/36085 [==============================] - 2s 44us/step - loss: 0.4914 - mean_squared_error: 0.0108 - val_loss: 0.4967 - val_mean_squared_error: 0.0106
# Epoch 63/200
# 36085/36085 [==============================] - 2s 42us/step - loss: 0.4915 - mean_squared_error: 0.0108 - val_loss: 0.4954 - val_mean_squared_error: 0.0108
# Epoch 64/200
# 36085/36085 [==============================] - 2s 45us/step - loss: 0.4913 - mean_squared_error: 0.0108 - val_loss: 0.4962 - val_mean_squared_error: 0.0106
# Epoch 65/200
# 36085/36085 [==============================] - 2s 43us/step - loss: 0.4913 - mean_squared_error: 0.0108 - val_loss: 0.4953 - val_mean_squared_error: 0.0111
# Epoch 66/200
# 36085/36085 [==============================] - 2s 42us/step - loss: 0.4917 - mean_squared_error: 0.0108 - val_loss: 0.4952 - val_mean_squared_error: 0.0110
# Epoch 67/200
# 36085/36085 [==============================] - 2s 42us/step - loss: 0.4911 - mean_squared_error: 0.0108 - val_loss: 0.4953 - val_mean_squared_error: 0.0111
# Epoch 68/200
# 36085/36085 [==============================] - 1s 41us/step - loss: 0.4915 - mean_squared_error: 0.0108 - val_loss: 0.4952 - val_mean_squared_error: 0.0109
# Epoch 69/200
# 36085/36085 [==============================] - 2s 45us/step - loss: 0.4915 - mean_squared_error: 0.0108 - val_loss: 0.4987 - val_mean_squared_error: 0.0116
# Epoch 70/200
# 36085/36085 [==============================] - 2s 45us/step - loss: 0.4916 - mean_squared_error: 0.0108 - val_loss: 0.4966 - val_mean_squared_error: 0.0114
# Epoch 71/200
# 36085/36085 [==============================] - 2s 48us/step - loss: 0.4913 - mean_squared_error: 0.0108 - val_loss: 0.4952 - val_mean_squared_error: 0.0110
# Epoch 72/200
# 36085/36085 [==============================] - 2s 43us/step - loss: 0.4914 - mean_squared_error: 0.0108 - val_loss: 0.4957 - val_mean_squared_error: 0.0107
# Epoch 73/200
# 36085/36085 [==============================] - 2s 47us/step - loss: 0.4912 - mean_squared_error: 0.0108 - val_loss: 0.4953 - val_mean_squared_error: 0.0109
# Epoch 74/200
# 36085/36085 [==============================] - 2s 42us/step - loss: 0.4914 - mean_squared_error: 0.0108 - val_loss: 0.4953 - val_mean_squared_error: 0.0109
# Epoch 75/200
# 36085/36085 [==============================] - 2s 44us/step - loss: 0.4915 - mean_squared_error: 0.0108 - val_loss: 0.4959 - val_mean_squared_error: 0.0107
# Epoch 76/200
# 36085/36085 [==============================] - 2s 46us/step - loss: 0.4915 - mean_squared_error: 0.0108 - val_loss: 0.4953 - val_mean_squared_error: 0.0111
# Epoch 77/200
# 36085/36085 [==============================] - 2s 43us/step - loss: 0.4910 - mean_squared_error: 0.0108 - val_loss: 0.4952 - val_mean_squared_error: 0.0109
# Epoch 78/200
# 36085/36085 [==============================] - 2s 45us/step - loss: 0.4915 - mean_squared_error: 0.0108 - val_loss: 0.4957 - val_mean_squared_error: 0.0112
# Epoch 79/200
# 36085/36085 [==============================] - 2s 45us/step - loss: 0.4914 - mean_squared_error: 0.0108 - val_loss: 0.4953 - val_mean_squared_error: 0.0109
# Epoch 80/200
# 36085/36085 [==============================] - 2s 44us/step - loss: 0.4913 - mean_squared_error: 0.0108 - val_loss: 0.4955 - val_mean_squared_error: 0.0108
# Epoch 81/200
# 36085/36085 [==============================] - 2s 43us/step - loss: 0.4915 - mean_squared_error: 0.0108 - val_loss: 0.4953 - val_mean_squared_error: 0.0108
# Epoch 82/200
# 36085/36085 [==============================] - 2s 42us/step - loss: 0.4912 - mean_squared_error: 0.0108 - val_loss: 0.4953 - val_mean_squared_error: 0.0110
# Epoch 83/200
# 36085/36085 [==============================] - 2s 46us/step - loss: 0.4913 - mean_squared_error: 0.0108 - val_loss: 0.4955 - val_mean_squared_error: 0.0108
# Epoch 84/200
# 36085/36085 [==============================] - 2s 44us/step - loss: 0.4910 - mean_squared_error: 0.0108 - val_loss: 0.4972 - val_mean_squared_error: 0.0105
# Epoch 85/200
# 36085/36085 [==============================] - 2s 42us/step - loss: 0.4916 - mean_squared_error: 0.0108 - val_loss: 0.4952 - val_mean_squared_error: 0.0110
# Epoch 86/200
# 36085/36085 [==============================] - 2s 47us/step - loss: 0.4914 - mean_squared_error: 0.0108 - val_loss: 0.4953 - val_mean_squared_error: 0.0110
# Epoch 87/200
# 36085/36085 [==============================] - 2s 43us/step - loss: 0.4916 - mean_squared_error: 0.0108 - val_loss: 0.4956 - val_mean_squared_error: 0.0108
# Epoch 88/200
# 36085/36085 [==============================] - 2s 46us/step - loss: 0.4914 - mean_squared_error: 0.0108 - val_loss: 0.4952 - val_mean_squared_error: 0.0110
# Epoch 89/200
# 36085/36085 [==============================] - 2s 46us/step - loss: 0.4913 - mean_squared_error: 0.0108 - val_loss: 0.4960 - val_mean_squared_error: 0.0107
# Epoch 90/200
# 36085/36085 [==============================] - 2s 49us/step - loss: 0.4916 - mean_squared_error: 0.0108 - val_loss: 0.4952 - val_mean_squared_error: 0.0109
# Epoch 91/200
# 36085/36085 [==============================] - 2s 45us/step - loss: 0.4913 - mean_squared_error: 0.0108 - val_loss: 0.4956 - val_mean_squared_error: 0.0107
# Epoch 92/200
# 36085/36085 [==============================] - 2s 44us/step - loss: 0.4915 - mean_squared_error: 0.0108 - val_loss: 0.4954 - val_mean_squared_error: 0.0111
# Epoch 93/200
# 36085/36085 [==============================] - 2s 43us/step - loss: 0.4914 - mean_squared_error: 0.0108 - val_loss: 0.4964 - val_mean_squared_error: 0.0113
# Epoch 94/200
# 36085/36085 [==============================] - 2s 43us/step - loss: 0.4917 - mean_squared_error: 0.0109 - val_loss: 0.4953 - val_mean_squared_error: 0.0109
# Epoch 95/200
# 36085/36085 [==============================] - 2s 43us/step - loss: 0.4915 - mean_squared_error: 0.0108 - val_loss: 0.4952 - val_mean_squared_error: 0.0109
# Epoch 96/200
# 36085/36085 [==============================] - 2s 47us/step - loss: 0.4916 - mean_squared_error: 0.0108 - val_loss: 0.4971 - val_mean_squared_error: 0.0105
# Epoch 97/200
# 36085/36085 [==============================] - 2s 46us/step - loss: 0.4913 - mean_squared_error: 0.0108 - val_loss: 0.4952 - val_mean_squared_error: 0.0109
# Epoch 98/200
# 36085/36085 [==============================] - 2s 43us/step - loss: 0.4913 - mean_squared_error: 0.0108 - val_loss: 0.4958 - val_mean_squared_error: 0.0112
# Epoch 99/200
# 36085/36085 [==============================] - 2s 42us/step - loss: 0.4911 - mean_squared_error: 0.0108 - val_loss: 0.4954 - val_mean_squared_error: 0.0108
# Epoch 100/200
# 36085/36085 [==============================] - 2s 42us/step - loss: 0.4912 - mean_squared_error: 0.0108 - val_loss: 0.4954 - val_mean_squared_error: 0.0111
# Epoch 101/200
# 36085/36085 [==============================] - 2s 42us/step - loss: 0.4912 - mean_squared_error: 0.0108 - val_loss: 0.4953 - val_mean_squared_error: 0.0109
# Epoch 102/200
# 36085/36085 [==============================] - 2s 53us/step - loss: 0.4912 - mean_squared_error: 0.0108 - val_loss: 0.4954 - val_mean_squared_error: 0.0111
# Epoch 103/200
# 36085/36085 [==============================] - 2s 54us/step - loss: 0.4912 - mean_squared_error: 0.0108 - val_loss: 0.4953 - val_mean_squared_error: 0.0111
# Epoch 104/200
# 36085/36085 [==============================] - 2s 44us/step - loss: 0.4913 - mean_squared_error: 0.0108 - val_loss: 0.4961 - val_mean_squared_error: 0.0107
# Epoch 105/200
# 36085/36085 [==============================] - 2s 42us/step - loss: 0.4912 - mean_squared_error: 0.0108 - val_loss: 0.4953 - val_mean_squared_error: 0.0111
# Epoch 106/200
# 36085/36085 [==============================] - 1s 42us/step - loss: 0.4915 - mean_squared_error: 0.0108 - val_loss: 0.4956 - val_mean_squared_error: 0.0112
# Epoch 107/200
# 36085/36085 [==============================] - 2s 42us/step - loss: 0.4912 - mean_squared_error: 0.0108 - val_loss: 0.4958 - val_mean_squared_error: 0.0112
# Epoch 108/200
# 36085/36085 [==============================] - 2s 43us/step - loss: 0.4913 - mean_squared_error: 0.0108 - val_loss: 0.4966 - val_mean_squared_error: 0.0114
# Epoch 109/200
# 36085/36085 [==============================] - 2s 45us/step - loss: 0.4912 - mean_squared_error: 0.0108 - val_loss: 0.4955 - val_mean_squared_error: 0.0112
# Epoch 110/200
# 36085/36085 [==============================] - 2s 46us/step - loss: 0.4915 - mean_squared_error: 0.0108 - val_loss: 0.4971 - val_mean_squared_error: 0.0114
# Epoch 111/200
# 36085/36085 [==============================] - 2s 61us/step - loss: 0.4912 - mean_squared_error: 0.0108 - val_loss: 0.4953 - val_mean_squared_error: 0.0111
# Epoch 112/200
# 36085/36085 [==============================] - 3s 79us/step - loss: 0.4913 - mean_squared_error: 0.0108 - val_loss: 0.4961 - val_mean_squared_error: 0.0113
# Epoch 113/200
# 36085/36085 [==============================] - 2s 56us/step - loss: 0.4913 - mean_squared_error: 0.0108 - val_loss: 0.4975 - val_mean_squared_error: 0.0115
# Epoch 114/200
# 36085/36085 [==============================] - 2s 46us/step - loss: 0.4916 - mean_squared_error: 0.0108 - val_loss: 0.4953 - val_mean_squared_error: 0.0109
# Epoch 115/200
# 36085/36085 [==============================] - 2s 43us/step - loss: 0.4916 - mean_squared_error: 0.0108 - val_loss: 0.4952 - val_mean_squared_error: 0.0110
# Epoch 116/200
# 36085/36085 [==============================] - 2s 44us/step - loss: 0.4912 - mean_squared_error: 0.0108 - val_loss: 0.4952 - val_mean_squared_error: 0.0109
# Epoch 117/200
# 36085/36085 [==============================] - 2s 46us/step - loss: 0.4914 - mean_squared_error: 0.0108 - val_loss: 0.4954 - val_mean_squared_error: 0.0111
# Epoch 118/200
# 36085/36085 [==============================] - 2s 45us/step - loss: 0.4913 - mean_squared_error: 0.0108 - val_loss: 0.4955 - val_mean_squared_error: 0.0108
# Epoch 119/200
# 36085/36085 [==============================] - 2s 46us/step - loss: 0.4914 - mean_squared_error: 0.0108 - val_loss: 0.4953 - val_mean_squared_error: 0.0111
# Epoch 120/200
# 36085/36085 [==============================] - 2s 42us/step - loss: 0.4913 - mean_squared_error: 0.0108 - val_loss: 0.4953 - val_mean_squared_error: 0.0109
# Epoch 121/200
# 36085/36085 [==============================] - 2s 46us/step - loss: 0.4916 - mean_squared_error: 0.0108 - val_loss: 0.4956 - val_mean_squared_error: 0.0108
# Epoch 122/200
# 36085/36085 [==============================] - 2s 54us/step - loss: 0.4913 - mean_squared_error: 0.0108 - val_loss: 0.4953 - val_mean_squared_error: 0.0108
# Epoch 123/200
# 36085/36085 [==============================] - 2s 61us/step - loss: 0.4914 - mean_squared_error: 0.0108 - val_loss: 0.4973 - val_mean_squared_error: 0.0115
# Epoch 124/200
# 36085/36085 [==============================] - 2s 45us/step - loss: 0.4914 - mean_squared_error: 0.0108 - val_loss: 0.4959 - val_mean_squared_error: 0.0107
# Epoch 125/200
# 36085/36085 [==============================] - 2s 44us/step - loss: 0.4914 - mean_squared_error: 0.0108 - val_loss: 0.4955 - val_mean_squared_error: 0.0111
# Epoch 126/200
# 36085/36085 [==============================] - 2s 42us/step - loss: 0.4914 - mean_squared_error: 0.0108 - val_loss: 0.4957 - val_mean_squared_error: 0.0107
# Epoch 127/200
# 36085/36085 [==============================] - 2s 43us/step - loss: 0.4913 - mean_squared_error: 0.0108 - val_loss: 0.4972 - val_mean_squared_error: 0.0105
# Epoch 128/200
# 36085/36085 [==============================] - 2s 47us/step - loss: 0.4914 - mean_squared_error: 0.0108 - val_loss: 0.4958 - val_mean_squared_error: 0.0107
# Epoch 129/200
# 36085/36085 [==============================] - 2s 43us/step - loss: 0.4915 - mean_squared_error: 0.0109 - val_loss: 0.4997 - val_mean_squared_error: 0.0103
# Epoch 130/200
# 36085/36085 [==============================] - 2s 42us/step - loss: 0.4915 - mean_squared_error: 0.0108 - val_loss: 0.4952 - val_mean_squared_error: 0.0110
# Epoch 131/200
# 36085/36085 [==============================] - 2s 42us/step - loss: 0.4914 - mean_squared_error: 0.0108 - val_loss: 0.4954 - val_mean_squared_error: 0.0111
# Epoch 132/200
# 36085/36085 [==============================] - 2s 42us/step - loss: 0.4912 - mean_squared_error: 0.0108 - val_loss: 0.4978 - val_mean_squared_error: 0.0104
# Epoch 133/200
# 36085/36085 [==============================] - 2s 42us/step - loss: 0.4913 - mean_squared_error: 0.0108 - val_loss: 0.4952 - val_mean_squared_error: 0.0109
# Epoch 134/200
# 36085/36085 [==============================] - 2s 42us/step - loss: 0.4916 - mean_squared_error: 0.0108 - val_loss: 0.4959 - val_mean_squared_error: 0.0107
# Epoch 135/200
# 36085/36085 [==============================] - 1s 41us/step - loss: 0.4914 - mean_squared_error: 0.0108 - val_loss: 0.4953 - val_mean_squared_error: 0.0108
# Epoch 136/200
# 36085/36085 [==============================] - 2s 44us/step - loss: 0.4914 - mean_squared_error: 0.0108 - val_loss: 0.4974 - val_mean_squared_error: 0.0115
# Epoch 137/200
# 36085/36085 [==============================] - 2s 45us/step - loss: 0.4913 - mean_squared_error: 0.0108 - val_loss: 0.4960 - val_mean_squared_error: 0.0113
# Epoch 138/200
# 36085/36085 [==============================] - 2s 47us/step - loss: 0.4913 - mean_squared_error: 0.0108 - val_loss: 0.4960 - val_mean_squared_error: 0.0107
# Epoch 139/200
# 36085/36085 [==============================] - 2s 44us/step - loss: 0.4913 - mean_squared_error: 0.0108 - val_loss: 0.4953 - val_mean_squared_error: 0.0109
# Epoch 140/200
# 36085/36085 [==============================] - 2s 42us/step - loss: 0.4913 - mean_squared_error: 0.0108 - val_loss: 0.4958 - val_mean_squared_error: 0.0107
# Epoch 141/200
# 36085/36085 [==============================] - 2s 46us/step - loss: 0.4915 - mean_squared_error: 0.0108 - val_loss: 0.4953 - val_mean_squared_error: 0.0111
# Epoch 142/200
# 36085/36085 [==============================] - 2s 42us/step - loss: 0.4914 - mean_squared_error: 0.0108 - val_loss: 0.4987 - val_mean_squared_error: 0.0116
# Epoch 143/200
# 36085/36085 [==============================] - 2s 43us/step - loss: 0.4916 - mean_squared_error: 0.0108 - val_loss: 0.4954 - val_mean_squared_error: 0.0111
# Epoch 144/200
# 36085/36085 [==============================] - 2s 42us/step - loss: 0.4912 - mean_squared_error: 0.0108 - val_loss: 0.4953 - val_mean_squared_error: 0.0110
# Epoch 145/200
# 36085/36085 [==============================] - 2s 42us/step - loss: 0.4915 - mean_squared_error: 0.0108 - val_loss: 0.4957 - val_mean_squared_error: 0.0107
# Epoch 146/200
# 36085/36085 [==============================] - 2s 46us/step - loss: 0.4913 - mean_squared_error: 0.0108 - val_loss: 0.4953 - val_mean_squared_error: 0.0109
# Epoch 147/200
# 36085/36085 [==============================] - 2s 47us/step - loss: 0.4917 - mean_squared_error: 0.0108 - val_loss: 0.4954 - val_mean_squared_error: 0.0108
# Epoch 148/200
# 36085/36085 [==============================] - 2s 44us/step - loss: 0.4915 - mean_squared_error: 0.0108 - val_loss: 0.4952 - val_mean_squared_error: 0.0110
# Epoch 149/200
# 36085/36085 [==============================] - 2s 43us/step - loss: 0.4915 - mean_squared_error: 0.0108 - val_loss: 0.4961 - val_mean_squared_error: 0.0113
# Epoch 150/200
# 36085/36085 [==============================] - 2s 45us/step - loss: 0.4917 - mean_squared_error: 0.0108 - val_loss: 0.4963 - val_mean_squared_error: 0.0106
# Epoch 151/200
# 36085/36085 [==============================] - 2s 43us/step - loss: 0.4913 - mean_squared_error: 0.0108 - val_loss: 0.4961 - val_mean_squared_error: 0.0113
# Epoch 152/200
# 36085/36085 [==============================] - 2s 43us/step - loss: 0.4914 - mean_squared_error: 0.0108 - val_loss: 0.4955 - val_mean_squared_error: 0.0108
# Epoch 153/200
# 36085/36085 [==============================] - 2s 45us/step - loss: 0.4913 - mean_squared_error: 0.0108 - val_loss: 0.4992 - val_mean_squared_error: 0.0103
# Epoch 154/200
# 36085/36085 [==============================] - 2s 44us/step - loss: 0.4912 - mean_squared_error: 0.0108 - val_loss: 0.4954 - val_mean_squared_error: 0.0111
# Epoch 155/200
# 36085/36085 [==============================] - 2s 43us/step - loss: 0.4913 - mean_squared_error: 0.0108 - val_loss: 0.4956 - val_mean_squared_error: 0.0108
# Epoch 156/200
# 36085/36085 [==============================] - 2s 43us/step - loss: 0.4913 - mean_squared_error: 0.0108 - val_loss: 0.4953 - val_mean_squared_error: 0.0111
# Epoch 157/200
# 36085/36085 [==============================] - 2s 44us/step - loss: 0.4915 - mean_squared_error: 0.0108 - val_loss: 0.4960 - val_mean_squared_error: 0.0113
# Epoch 158/200
# 36085/36085 [==============================] - 2s 44us/step - loss: 0.4912 - mean_squared_error: 0.0108 - val_loss: 0.4957 - val_mean_squared_error: 0.0112
# Epoch 159/200
# 36085/36085 [==============================] - 2s 48us/step - loss: 0.4914 - mean_squared_error: 0.0108 - val_loss: 0.4962 - val_mean_squared_error: 0.0106
# Epoch 160/200
# 36085/36085 [==============================] - 2s 44us/step - loss: 0.4915 - mean_squared_error: 0.0108 - val_loss: 0.4969 - val_mean_squared_error: 0.0114
# Epoch 161/200
# 36085/36085 [==============================] - 2s 43us/step - loss: 0.4915 - mean_squared_error: 0.0109 - val_loss: 0.4952 - val_mean_squared_error: 0.0110
# Epoch 162/200
# 36085/36085 [==============================] - 2s 43us/step - loss: 0.4913 - mean_squared_error: 0.0108 - val_loss: 0.4953 - val_mean_squared_error: 0.0109
# Epoch 163/200
# 36085/36085 [==============================] - 2s 43us/step - loss: 0.4912 - mean_squared_error: 0.0108 - val_loss: 0.4953 - val_mean_squared_error: 0.0108
# Epoch 164/200
# 36085/36085 [==============================] - 2s 43us/step - loss: 0.4915 - mean_squared_error: 0.0108 - val_loss: 0.4957 - val_mean_squared_error: 0.0112
# Epoch 165/200
# 36085/36085 [==============================] - 2s 42us/step - loss: 0.4916 - mean_squared_error: 0.0108 - val_loss: 0.4957 - val_mean_squared_error: 0.0107
# Epoch 166/200
# 36085/36085 [==============================] - 2s 43us/step - loss: 0.4912 - mean_squared_error: 0.0108 - val_loss: 0.4952 - val_mean_squared_error: 0.0110
# Epoch 167/200
# 36085/36085 [==============================] - 2s 43us/step - loss: 0.4913 - mean_squared_error: 0.0108 - val_loss: 0.4961 - val_mean_squared_error: 0.0107
# Epoch 168/200
# 36085/36085 [==============================] - 2s 42us/step - loss: 0.4914 - mean_squared_error: 0.0108 - val_loss: 0.4966 - val_mean_squared_error: 0.0114
# Epoch 169/200
# 36085/36085 [==============================] - 2s 43us/step - loss: 0.4913 - mean_squared_error: 0.0108 - val_loss: 0.4958 - val_mean_squared_error: 0.0107
# Epoch 170/200
# 36085/36085 [==============================] - 2s 43us/step - loss: 0.4914 - mean_squared_error: 0.0108 - val_loss: 0.4953 - val_mean_squared_error: 0.0109
# Epoch 171/200
# 36085/36085 [==============================] - 2s 43us/step - loss: 0.4913 - mean_squared_error: 0.0108 - val_loss: 0.4964 - val_mean_squared_error: 0.0106
# Epoch 172/200
# 36085/36085 [==============================] - 2s 43us/step - loss: 0.4914 - mean_squared_error: 0.0108 - val_loss: 0.4955 - val_mean_squared_error: 0.0108
# Epoch 173/200
# 36085/36085 [==============================] - 2s 43us/step - loss: 0.4913 - mean_squared_error: 0.0108 - val_loss: 0.4952 - val_mean_squared_error: 0.0110
# Epoch 174/200
# 36085/36085 [==============================] - 2s 42us/step - loss: 0.4913 - mean_squared_error: 0.0108 - val_loss: 0.4953 - val_mean_squared_error: 0.0109
# Epoch 175/200
# 36085/36085 [==============================] - 2s 43us/step - loss: 0.4914 - mean_squared_error: 0.0108 - val_loss: 0.4954 - val_mean_squared_error: 0.0111
# Epoch 176/200
# 36085/36085 [==============================] - 2s 43us/step - loss: 0.4915 - mean_squared_error: 0.0108 - val_loss: 0.4964 - val_mean_squared_error: 0.0106
# Epoch 177/200
# 36085/36085 [==============================] - 2s 43us/step - loss: 0.4914 - mean_squared_error: 0.0108 - val_loss: 0.4959 - val_mean_squared_error: 0.0107
# Epoch 178/200
# 36085/36085 [==============================] - 2s 42us/step - loss: 0.4912 - mean_squared_error: 0.0108 - val_loss: 0.4956 - val_mean_squared_error: 0.0108
# Epoch 179/200
# 36085/36085 [==============================] - 2s 43us/step - loss: 0.4914 - mean_squared_error: 0.0108 - val_loss: 0.4955 - val_mean_squared_error: 0.0112
# Epoch 180/200
# 36085/36085 [==============================] - 2s 42us/step - loss: 0.4914 - mean_squared_error: 0.0108 - val_loss: 0.4973 - val_mean_squared_error: 0.0115
# Epoch 181/200
# 36085/36085 [==============================] - 2s 42us/step - loss: 0.4915 - mean_squared_error: 0.0108 - val_loss: 0.4954 - val_mean_squared_error: 0.0108
# Epoch 182/200
# 36085/36085 [==============================] - 2s 42us/step - loss: 0.4916 - mean_squared_error: 0.0108 - val_loss: 0.4954 - val_mean_squared_error: 0.0108
# Epoch 183/200
# 36085/36085 [==============================] - 2s 42us/step - loss: 0.4913 - mean_squared_error: 0.0108 - val_loss: 0.4952 - val_mean_squared_error: 0.0110
# Epoch 184/200
# 36085/36085 [==============================] - 2s 42us/step - loss: 0.4915 - mean_squared_error: 0.0108 - val_loss: 0.4953 - val_mean_squared_error: 0.0111
# Epoch 185/200
# 36085/36085 [==============================] - 2s 42us/step - loss: 0.4916 - mean_squared_error: 0.0108 - val_loss: 0.4989 - val_mean_squared_error: 0.0116
# Epoch 186/200
# 36085/36085 [==============================] - 2s 44us/step - loss: 0.4915 - mean_squared_error: 0.0108 - val_loss: 0.4953 - val_mean_squared_error: 0.0109
# Epoch 187/200
# 36085/36085 [==============================] - 2s 46us/step - loss: 0.4912 - mean_squared_error: 0.0108 - val_loss: 0.4954 - val_mean_squared_error: 0.0111
# Epoch 188/200
# 36085/36085 [==============================] - 2s 43us/step - loss: 0.4914 - mean_squared_error: 0.0108 - val_loss: 0.4952 - val_mean_squared_error: 0.0110
# Epoch 189/200
# 36085/36085 [==============================] - 2s 49us/step - loss: 0.4912 - mean_squared_error: 0.0108 - val_loss: 0.4953 - val_mean_squared_error: 0.0109
# Epoch 190/200
# 36085/36085 [==============================] - 2s 52us/step - loss: 0.4916 - mean_squared_error: 0.0108 - val_loss: 0.4952 - val_mean_squared_error: 0.0109
# Epoch 191/200
# 36085/36085 [==============================] - 2s 58us/step - loss: 0.4911 - mean_squared_error: 0.0108 - val_loss: 0.4953 - val_mean_squared_error: 0.0109
# Epoch 192/200
# 36085/36085 [==============================] - 3s 74us/step - loss: 0.4915 - mean_squared_error: 0.0108 - val_loss: 0.4963 - val_mean_squared_error: 0.0113
# Epoch 193/200
# 36085/36085 [==============================] - 3s 87us/step - loss: 0.4914 - mean_squared_error: 0.0108 - val_loss: 0.4952 - val_mean_squared_error: 0.0110
# Epoch 194/200
# 36085/36085 [==============================] - 3s 72us/step - loss: 0.4911 - mean_squared_error: 0.0108 - val_loss: 0.4965 - val_mean_squared_error: 0.0114
# Epoch 195/200
# 36085/36085 [==============================] - 2s 47us/step - loss: 0.4916 - mean_squared_error: 0.0108 - val_loss: 0.4954 - val_mean_squared_error: 0.0111
# Epoch 196/200
# 36085/36085 [==============================] - 2s 53us/step - loss: 0.4913 - mean_squared_error: 0.0108 - val_loss: 0.4953 - val_mean_squared_error: 0.0110
# Epoch 197/200
# 36085/36085 [==============================] - 1s 40us/step - loss: 0.4913 - mean_squared_error: 0.0108 - val_loss: 0.4956 - val_mean_squared_error: 0.0108
# Epoch 198/200
# 36085/36085 [==============================] - 1s 40us/step - loss: 0.4913 - mean_squared_error: 0.0108 - val_loss: 0.4952 - val_mean_squared_error: 0.0110
# Epoch 199/200
# 36085/36085 [==============================] - 2s 42us/step - loss: 0.4913 - mean_squared_error: 0.0108 - val_loss: 0.4959 - val_mean_squared_error: 0.0113
# Epoch 200/200
# 36085/36085 [==============================] - 1s 40us/step - loss: 0.4913 - mean_squared_error: 0.0108 - val_loss: 0.4957 - val_mean_squared_error: 0.0112

# %% [markdown]
# ### 5.1 Results
# __Following results are not correct!!__

# %%
#error plots
S0=1.
y_test_re       = yinversetransform(y_test)
prediction_list = [yinversetransform(NN3.predict(X_test_trafo3[i].reshape(1,Nparameters))[0]) for i in range(len(X_test_trafo3))]
prediction      = np.asarray(prediction_list)
Ntest           = prediction.shape[0]
err_rel_list = np.abs((y_test_re-prediction)/y_test_re)
err_rel_mat  = err_rel_list.reshape((Ntest,Nmaturities,Nstrikes))
idx = np.argsort(np.max(err_rel_mat,axis=tuple([1,2])), axis=None)
#bad_idx = idx[:-200]
err_list = np.square((y_test_re-prediction))
err_mat  = err_list.reshape((Ntest,Nmaturities,Nstrikes))
bad_idx = idx
#from matplotlib.colors import LogNorm
plt.figure(figsize=(14,4))
ax=plt.subplot(2,3,1)
err1 = 100*np.mean(err_rel_mat[bad_idx,:,:],axis=0)
plt.title("Average relative error",fontsize=15,y=1.04)
plt.imshow(err1)#,norm=LogNorm(vmin=err1.min(), vmax=err1.max()))
plt.setp(ax.get_xticklabels(), rotation=30, horizontalalignment='right')
plt.colorbar(format=mtick.PercentFormatter())
ax.set_xticks(np.linspace(0,Nstrikes-1,Nstrikes))
ax.set_xticklabels(strikes)
ax.set_yticks(np.linspace(0,Nmaturities-1,Nmaturities))
ax.set_yticklabels(maturities)
plt.xlabel("Strike",fontsize=15,labelpad=5)
plt.ylabel("Maturity",fontsize=15,labelpad=5)
ax=plt.subplot(2,3,2)
err2 = 100*np.std(err_rel_mat[bad_idx,:,:],axis = 0)
plt.title("Std relative error",fontsize=15,y=1.04)
plt.imshow(err2)#,norm=LogNorm(vmin=err2.min(), vmax=err2.max()))
plt.colorbar(format=mtick.PercentFormatter())
plt.setp(ax.get_xticklabels(), rotation=30, horizontalalignment='right')
ax.set_xticks(np.linspace(0,Nstrikes-1,Nstrikes))
ax.set_xticklabels(strikes)
ax.set_yticks(np.linspace(0,Nmaturities-1,Nmaturities))
ax.set_yticklabels(maturities)
plt.xlabel("Strike",fontsize=15,labelpad=5)
plt.ylabel("Maturity",fontsize=15,labelpad=5)
ax=plt.subplot(2,3,3)
err3 = 100*np.max(err_rel_mat[bad_idx,:,:],axis = 0)
plt.title("Maximum relative error",fontsize=15,y=1.04)
plt.imshow(err3)#,norm=LogNorm(vmin=err3.min(), vmax=err3.max()))
plt.colorbar(format=mtick.PercentFormatter())
plt.setp(ax.get_xticklabels(), rotation=30, horizontalalignment='right')
ax.set_xticks(np.linspace(0,Nstrikes-1,Nstrikes))
ax.set_xticklabels(strikes)
ax.set_yticks(np.linspace(0,Nmaturities-1,Nmaturities))
ax.set_yticklabels(maturities)
plt.xlabel("Strike",fontsize=15,labelpad=5)
plt.ylabel("Maturity",fontsize=15,labelpad=5)
ax=plt.subplot(2,3,4)
err1 = np.sqrt(np.mean(err_mat[bad_idx,:,:],axis=0))
plt.title("RMSE",fontsize=15,y=1.04)
plt.imshow(err1)#,norm=LogNorm(vmin=err1.min(), vmax=err1.max()))
plt.colorbar(format=mtick.PercentFormatter())
plt.setp(ax.get_xticklabels(), rotation=30, horizontalalignment='right')
ax.set_xticks(np.linspace(0,Nstrikes-1,Nstrikes))
ax.set_xticklabels(strikes)
ax.set_yticks(np.linspace(0,Nmaturities-1,Nmaturities))
ax.set_yticklabels(maturities)
plt.xlabel("Strike",fontsize=15,labelpad=5)
plt.ylabel("Maturity",fontsize=15,labelpad=5)
ax=plt.subplot(2,3,5)
err2 = np.std(err_mat[bad_idx,:,:],axis = 0)
plt.title("Std MSE",fontsize=15,y=1.04)
plt.imshow(err2)#,norm=LogNorm(vmin=err2.min(), vmax=err2.max()))
plt.colorbar(format=mtick.PercentFormatter())
plt.setp(ax.get_xticklabels(), rotation=30, horizontalalignment='right')
ax.set_xticks(np.linspace(0,Nstrikes-1,Nstrikes))
ax.set_xticklabels(strikes)
ax.set_yticks(np.linspace(0,Nmaturities-1,Nmaturities))
ax.set_yticklabels(maturities)
plt.xlabel("Strike",fontsize=15,labelpad=5)
plt.ylabel("Maturity",fontsize=15,labelpad=5)
ax=plt.subplot(2,3,6)
err3 = np.max(err_mat[bad_idx,:,:],axis = 0)
plt.title("Maximum MSE",fontsize=15,y=1.04)
plt.imshow(err3)#,norm=LogNorm(vmin=err3.min(), vmax=err3.max()))
plt.colorbar(format=mtick.PercentFormatter())
ax.set_xticks(np.linspace(0,Nstrikes-1,Nstrikes))
ax.set_xticklabels(strikes)
ax.set_yticks(np.linspace(0,Nmaturities-1,Nmaturities))
ax.set_yticklabels(maturities)
plt.xlabel("Strike",fontsize=15,labelpad=5)
plt.ylabel("Maturity",fontsize=15,labelpad=5)

plt.setp(ax.get_xticklabels(), rotation=30, horizontalalignment='right')
plt.tight_layout()
plt.savefig('HNG_NN_old_Errors.png', dpi=300)
plt.show()



#==============================================================================
#surface
import random
test_sample = random.randint(0,len(y_test))
test_sample = idx[-1]
#test_sample = idx[0]

y_test_sample = y_test_re[test_sample,:]
y_predict_sample = prediction_list[test_sample]
y_test_sample_p = np.reshape(y_test_sample, (Nmaturities, Nstrikes))
y_predict_sample_p = np.reshape(y_predict_sample, (Nmaturities, Nstrikes))
diff = y_test_sample_p-y_predict_sample_p 
rel_diff = np.abs(y_test_sample_p-y_predict_sample_p)/(y_test_sample_p)
    
# This import registers the 3D projection, but is otherwise unused.
from mpl_toolkits.mplot3d import Axes3D  # noqa: F401 unused import
from matplotlib import cm
from matplotlib.ticker import LinearLocator, FormatStrFormatter

fig = plt.figure()
ax = fig.gca(projection='3d')

# Make data.
X = strikes
Y = maturities
X, Y = np.meshgrid(X, Y)


#ax.contour3D(X, Y, Z, 50, cmap='binary')
ax.plot_surface(X, Y, y_test_sample_p, rstride=1, cstride=1,
                cmap='viridis', edgecolor='none')
ax.plot_surface(X, Y, y_predict_sample_p , rstride=1, cstride=1,
                cmap='viridis', edgecolor='none')
#ax.plot_surface(X, Y, rel_diff, rstride=1, cstride=1,
#                cmap='viridis', edgecolor='none')
ax.set_xlabel('Strikes')
ax.set_ylabel('Maturities')
#ax.set_zlabel('rel. err');
plt.show()


#==============================================================================
#smile
sample_ind = 13
X_sample = X_test_trafo3[sample_ind]
y_sample = y_test[sample_ind]
#print(scale.inverse_transform(y_sample))

prediction=yinversetransform(NN3.predict(X_sample.reshape(1,Nparameters))[0])
plt.figure(figsize=(14,12))
for i in range(Nmaturities):
    plt.subplot(4,4,i+1)
    
    plt.plot(np.log(strikes/S0),y_sample[i*Nstrikes:(i+1)*Nstrikes],'b',label="Input data")
    plt.plot(np.log(strikes/S0),prediction[i*Nstrikes:(i+1)*Nstrikes],'--r',label=" NN Approx")
    #plt.ylim(0.22, 0.26)
    
    plt.title("Maturity=%1.2f "%maturities[i])
    plt.xlabel("log-moneyness")
    plt.ylabel("Implied vol")
    
    plt.legend()
plt.tight_layout()
plt.savefig('HNG_old_smile.png', dpi=300)
plt.show()
