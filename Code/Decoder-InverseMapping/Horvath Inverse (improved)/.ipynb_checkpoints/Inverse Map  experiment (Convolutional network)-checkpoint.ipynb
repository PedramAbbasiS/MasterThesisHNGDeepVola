# %% [markdown]
# # Model calibrations using ML
#
# ## Structure
#
# # We apply the inverse map approach to solve the calibration problem
#
# ## Authors
#
# Dr. Blanka Horvath, Aitor Muguruza Gonzalez, Mehdi Tomas

# %% [markdown]
# ## Extract data

# %%
import os
os.chdir("..\Data")

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import gzip
f = gzip.GzipFile('rBergomiTrainSet.txt.gz', "r")
dat=np.load(f)
print(dat.shape)
xx=dat[:,:4]
yy=dat[:,4:]
print(xx.shape)
strikes=np.array([0.5,0.6,0.7,0.8,0.9,1.0,1.1,1.2,1.3,1.4,1.5 ])
maturities=np.array([0.1,0.3,0.6,0.9,1.2,1.5,1.8,2.0 ])
# Out:
# (40000, 92)
# (40000, 4)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(
    yy, xx, test_size=0.15, random_state=42)
from sklearn.preprocessing import StandardScaler

scale = StandardScaler()
scale2=  StandardScaler()
y_train_transform = scale.fit_transform(y_train)
y_test_transform = scale.transform(y_test)
x_train_transform = scale2.fit_transform(X_train)
x_test_transform = scale2.transform(X_test)

# %%
strikes_dim=len(strikes)
maturities_dim=len(maturities)

# %% [markdown]
# # Convolutional nets

# %% [markdown]
# ## We use a custom activation function to make sure that model parameters are within admisible bounds

# %% [markdown]
# ### (No need to run the training optimal parameters are stored in a .h5 file)

# %%
import keras
from keras.layers import Activation
from keras.layers import Dense
from keras import backend as K
from keras.utils.generic_utils import get_custom_objects
input1 = keras.layers.Input(shape=(len(maturities),len(strikes),1))
x1 = keras.layers.Convolution2D(16, (3, 3),activation='elu')(input1)
input2=keras.layers.Input(shape=(6,9, 16) )
x2=keras.layers.MaxPooling2D(pool_size=(2,2))(x1)
input3=keras.layers.Input(shape=(3,4, 16) )
x3=keras.layers.Flatten()(x2)
x4=keras.layers.Dense(50,activation = 'elu')(x3)
ub=scale.transform(np.array([[0.26,4,1.0,0.5]]))[0]
lb=scale.transform(np.array([[0.001,0.01,-1.0,0.001]]))[0]
def custom_activation1(x):
    return (K.tanh(x))*(ub[0] - lb[0]) *0.5 + (ub[0] + lb[0])*0.5
def custom_activation2(x):
    return (K.tanh(x))*(ub[1] - lb[1]) *0.5 + (ub[1] + lb[1])*0.5
def custom_activation3(x):
    return K.tanh(x)*(ub[2] - lb[2]) *0.5 + (ub[3] + lb[2])*0.5
def custom_activation4(x):
    return K.tanh(x)*(ub[3] - lb[3]) *0.5 + (ub[3] + lb[3])*0.5
get_custom_objects().update({'custom_activation1': Activation(custom_activation1)})
get_custom_objects().update({'custom_activation2': Activation(custom_activation2)})
get_custom_objects().update({'custom_activation3': Activation(custom_activation3)})
get_custom_objects().update({'custom_activation4': Activation(custom_activation4)})
seq1 = Dense(1, activation = 'custom_activation1')(x4)
#seq11 = Dense(1, activation = 'custom_activation1')(seq1)
seq2 = Dense(1, activation = 'custom_activation2')(x4)
#seq22 = Dense(1, activation = 'custom_activation2')(seq2)
seq3 = Dense(8, activation = 'custom_activation3')(x4)
seq33 = Dense(1, activation = 'custom_activation3')(seq3)
seq4 = Dense(5, activation = 'custom_activation3')(x4)
seq44 = Dense(1, activation = 'custom_activation4')(seq4)

acum = keras.layers.merge.concatenate([seq1, seq2, seq33,seq44], axis=-1)

model = keras.models.Model(inputs=input1, outputs=acum)
model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_19 (InputLayer)           (None, 8, 11, 1)     0
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 6, 9, 16)     160         input_19[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_7 (MaxPooling2D)  (None, 3, 4, 16)     0           conv2d_7[0][0]
# __________________________________________________________________________________________________
# flatten_7 (Flatten)             (None, 192)          0           max_pooling2d_7[0][0]
# __________________________________________________________________________________________________
# dense_51 (Dense)                (None, 50)           9650        flatten_7[0][0]
# __________________________________________________________________________________________________
# dense_54 (Dense)                (None, 8)            408         dense_51[0][0]
# __________________________________________________________________________________________________
# dense_56 (Dense)                (None, 5)            255         dense_51[0][0]
# __________________________________________________________________________________________________
# dense_52 (Dense)                (None, 1)            51          dense_51[0][0]
# __________________________________________________________________________________________________
# dense_53 (Dense)                (None, 1)            51          dense_51[0][0]
# __________________________________________________________________________________________________
# dense_55 (Dense)                (None, 1)            9           dense_54[0][0]
# __________________________________________________________________________________________________
# dense_57 (Dense)                (None, 1)            6           dense_56[0][0]
# __________________________________________________________________________________________________
# concatenate_7 (Concatenate)     (None, 4)            0           dense_52[0][0]
#                                                                  dense_53[0][0]
#                                                                  dense_55[0][0]
#                                                                  dense_57[0][0]
# ==================================================================================================
# Total params: 10,590
# Trainable params: 10,590
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
from keras.callbacks import EarlyStopping
# Configure Early Stopping
patience = 25
earlystop = EarlyStopping(monitor="val_loss",
                          min_delta=0,
                          mode="min",
                          verbose=1, 
                          patience=patience)
def root_mean_squared_error(y_true, y_pred):
        return K.sqrt(K.mean(K.square(y_pred - y_true)))
model.compile(loss = root_mean_squared_error, optimizer = "adam")
A=x_train_transform.reshape(len(x_train_transform),len(maturities),len(strikes),1)
B=x_test_transform.reshape(len(x_test_transform),len(maturities),len(strikes),1)
model.fit(A,y_train_transform, batch_size=64,validation_data = (B,y_test_transform),epochs = 200, verbose = True,shuffle=1,callbacks=[earlystop])
# Out:
# Train on 34000 samples, validate on 6000 samples
# Epoch 1/200
# 34000/34000 [==============================] - 6s 178us/step - loss: 0.3096 - val_loss: 0.2024
# Epoch 2/200
# 34000/34000 [==============================] - 3s 102us/step - loss: 0.1869 - val_loss: 0.1853
# Epoch 3/200
# 34000/34000 [==============================] - 3s 102us/step - loss: 0.1632 - val_loss: 0.1477
# Epoch 4/200
# 34000/34000 [==============================] - 3s 103us/step - loss: 0.1485 - val_loss: 0.1513
# Epoch 5/200
# 34000/34000 [==============================] - 4s 112us/step - loss: 0.1395 - val_loss: 0.1416
# Epoch 6/200
# 34000/34000 [==============================] - 3s 98us/step - loss: 0.1303 - val_loss: 0.1402
# Epoch 7/200
# 34000/34000 [==============================] - 3s 96us/step - loss: 0.1220 - val_loss: 0.1204
# Epoch 8/200
# 34000/34000 [==============================] - 3s 96us/step - loss: 0.1167 - val_loss: 0.1085
# Epoch 9/200
# 34000/34000 [==============================] - 3s 92us/step - loss: 0.1096 - val_loss: 0.1073
# Epoch 10/200
# 34000/34000 [==============================] - 3s 93us/step - loss: 0.1047 - val_loss: 0.1133
# Epoch 11/200
# 34000/34000 [==============================] - 3s 93us/step - loss: 0.0998 - val_loss: 0.0989
# Epoch 12/200
# 34000/34000 [==============================] - 3s 92us/step - loss: 0.0960 - val_loss: 0.0876
# Epoch 13/200
# 34000/34000 [==============================] - 3s 95us/step - loss: 0.0910 - val_loss: 0.0862
# Epoch 14/200
# 34000/34000 [==============================] - 3s 90us/step - loss: 0.0898 - val_loss: 0.0815
# Epoch 15/200
# 34000/34000 [==============================] - 3s 90us/step - loss: 0.0827 - val_loss: 0.0744
# Epoch 16/200
# 34000/34000 [==============================] - 3s 90us/step - loss: 0.0801 - val_loss: 0.0820
# Epoch 17/200
# 34000/34000 [==============================] - 3s 90us/step - loss: 0.0772 - val_loss: 0.0848
# Epoch 18/200
# 34000/34000 [==============================] - 3s 90us/step - loss: 0.0733 - val_loss: 0.0748
# Epoch 19/200
# 34000/34000 [==============================] - 3s 90us/step - loss: 0.0728 - val_loss: 0.0655
# Epoch 20/200
# 34000/34000 [==============================] - 3s 89us/step - loss: 0.0658 - val_loss: 0.0590
# Epoch 21/200
# 34000/34000 [==============================] - 3s 90us/step - loss: 0.0659 - val_loss: 0.0713
# Epoch 22/200
# 34000/34000 [==============================] - 3s 90us/step - loss: 0.0630 - val_loss: 0.0676
# Epoch 23/200
# 34000/34000 [==============================] - 3s 90us/step - loss: 0.0625 - val_loss: 0.0687
# Epoch 24/200
# 34000/34000 [==============================] - 3s 89us/step - loss: 0.0592 - val_loss: 0.0704
# Epoch 25/200
# 34000/34000 [==============================] - 3s 90us/step - loss: 0.
200
# 34000/34000 [==============================] - 3s 91us/step - loss: 0.0230 - val_loss: 0.0250
# Epoch 108/200
# 34000/34000 [==============================] - 3s 89us/step - loss: 0.0252 - val_loss: 0.0245
# Epoch 109/200
# 34000/34000 [==============================] - 3s 89us/step - loss: 0.0233 - val_loss: 0.0289
# Epoch 110/200
# 34000/34000 [==============================] - 3s 90us/step - loss: 0.0237 - val_loss: 0.0311
# Epoch 111/200
# 34000/34000 [==============================] - 3s 89us/step - loss: 0.0228 - val_loss: 0.0245
# Epoch 112/200
# 34000/34000 [==============================] - 3s 94us/step - loss: 0.0234 - val_loss: 0.0259
# Epoch 113/200
# 34000/34000 [==============================] - 4s 108us/step - loss: 0.0236 - val_loss: 0.0225
# Epoch 114/200
# 34000/34000 [==============================] - 3s 91us/step - loss: 0.0243 - val_loss: 0.0276
# Epoch 115/200
# 34000/34000 [==============================] - 3s 90us/step - loss: 0.0230 - val_loss: 0.0207
# Epoch 116/200
# 34000/34000 [==============================] - 3s 95us/step - loss: 0.0230 - val_loss: 0.0232
# Epoch 117/200
# 34000/34000 [==============================] - 3s 91us/step - loss: 0.0226 - val_loss: 0.0258
# Epoch 118/200
# 34000/34000 [==============================] - 3s 90us/step - loss: 0.0238 - val_loss: 0.0246
# Epoch 119/200
# 34000/34000 [==============================] - 3s 90us/step - loss: 0.0238 - val_loss: 0.0341
# Epoch 120/200
# 34000/34000 [==============================] - 3s 90us/step - loss: 0.0236 - val_loss: 0.0221
# Epoch 121/200
# 34000/34000 [==============================] - 3s 89us/step - loss: 0.0220 - val_loss: 0.0200
# Epoch 122/200
# 34000/34000 [==============================] - 3s 90us/step - loss: 0.0219 - val_loss: 0.0204
# Epoch 123/200
# 34000/34000 [==============================] - 3s 90us/step - loss: 0.0224 - val_loss: 0.0325
# Epoch 124/200
# 34000/34000 [==============================] - 3s 89us/step - loss: 0.0219 - val_loss: 0.0224
# Epoch 125/200
# 34000/34000 [==============================] - 3s 90us/step - loss: 0.0237 - val_loss: 0.0266
# Epoch 126/200
# 34000/34000 [==============================] - 3s 89us/step - loss: 0.0222 - val_loss: 0.0202
# Epoch 127/200
# 34000/34000 [==============================] - 3s 90us/step - loss: 0.0220 - val_loss: 0.0185
# Epoch 128/200
# 34000/34000 [==============================] - 3s 93us/step - loss: 0.0219 - val_loss: 0.0306
# Epoch 129/200
# 34000/34000 [==============================] - 3s 90us/step - loss: 0.0219 - val_loss: 0.0207
# Epoch 130/200
# 34000/34000 [==============================] - 3s 89us/step - loss: 0.0217 - val_loss: 0.0224
# Epoch 131/200
# 34000/34000 [==============================] - 3s 90us/step - loss: 0.0228 - val_loss: 0.0254
# Epoch 132/200
# 34000/34000 [==============================] - 3s 90us/step - loss: 0.0221 - val_loss: 0.0239
# Epoch 133/200
# 34000/34000 [==============================] - 3s 89us/step - loss: 0.0220 - val_loss: 0.0226
# Epoch 134/200
# 34000/34000 [==============================] - 3s 89us/step - loss: 0.0224 - val_loss: 0.0216
# Epoch 135/200
# 34000/34000 [==============================] - 3s 90us/step - loss: 0.0215 - val_loss: 0.0201
# Epoch 136/200
# 34000/34000 [==============================] - 3s 97us/step - loss: 0.0212 - val_loss: 0.0235
# Epoch 137/200
# 34000/34000 [==============================] - 3s 102us/step - loss: 0.0216 - val_loss: 0.0265
# Epoch 138/200
# 34000/34000 [==============================] - 6s 175us/step - loss: 0.0215 - val_loss: 0.0240
# Epoch 139/200
# 34000/34000 [==============================] - 4s 121us/step - loss: 0.0211 - val_loss: 0.0221
# Epoch 140/200
# 34000/34000 [==============================] - 3s 91us/step - loss: 0.0211 - val_loss: 0.0277
# Epoch 141/200
# 34000/34000 [==============================] - 5s 146us/step - loss: 0.0212 - val_loss: 0.0333
# Epoch 142/200
# 34000/34000 [==============================] - 4s 126us/step - loss: 0.0218 - val_loss: 0.0305
# Epoch 143/200
# 34000/34000 [==============================] - 5s 160us/step - loss: 0.0208 - val_loss: 0.0228
# Epoch 144/200
# 34000/34000 [==============================] - 4s 116us/step - loss: 0.0208 - val_loss: 0.0175
# Epoch 145/200
# 34000/34000 [==============================] - 3s 95us/step - loss: 0.0204 - val_loss: 0.0178
# Epoch 146/200
# 34000/34000 [==============================] - 3s 91us/step - loss: 0.0211 - val_loss: 0.0190
# Epoch 147/200
# 34000/34000 [==============================] - 3s 90us/step - loss: 0.0201 - val_loss: 0.0205
# Epoch 148/200
# 34000/34000 [==============================] - 3s 90us/step - loss: 0.0210 - val_loss: 0.0372
# Epoch 149/200
# 34000/34000 [==============================] - 3s 90us/step - loss: 0.0205 - val_loss: 0.0191
# Epoch 150/200
# 34000/34000 [==============================] - 3s 90us/step - loss: 0.
# Epoch 184/200
# 34000/34000 [==============================] - 3s 93us/step - loss: 0.0193 - val_loss: 0.0247
# Epoch 185/200
# 34000/34000 [==============================] - 3s 98us/step - loss: 0.0184 - val_loss: 0.0207
# Epoch 186/200
# 34000/34000 [==============================] - 4s 104us/step - loss: 0.0187 - val_loss: 0.0150
# Epoch 187/200
# 34000/34000 [==============================] - 4s 113us/step - loss: 0.0185 - val_loss: 0.0205
# Epoch 188/200
# 34000/34000 [==============================] - 4s 106us/step - loss: 0.0187 - val_loss: 0.0192
# Epoch 189/200
# 34000/34000 [==============================] - 3s 95us/step - loss: 0.0187 - val_loss: 0.0214
# Epoch 190/200
# 34000/34000 [==============================] - 3s 94us/step - loss: 0.0195 - val_loss: 0.0294
# Epoch 191/200
# 34000/34000 [==============================] - 3s 95us/step - loss: 0.0187 - val_loss: 0.0256
# Epoch 192/200
# 34000/34000 [==============================] - 3s 95us/step - loss: 0.0184 - val_loss: 0.0202
# Epoch 193/200
# 34000/34000 [==============================] - 3s 93us/step - loss: 0.0174 - val_loss: 0.0261
# Epoch 194/200
# 34000/34000 [==============================] - 3s 91us/step - loss: 0.0187 - val_loss: 0.0140
# Epoch 195/200
# 34000/34000 [==============================] - 3s 93us/step - loss: 0.0183 - val_loss: 0.0200
# Epoch 196/200
# 34000/34000 [==============================] - 4s 110us/step - loss: 0.0182 - val_loss: 0.0216
# Epoch 197/200
# 34000/34000 [==============================] - 3s 100us/step - loss: 0.0187 - val_loss: 0.0319
# Epoch 198/200
# 34000/34000 [==============================] - 3s 98us/step - loss: 0.0194 - val_loss: 0.0215
# Epoch 199/200
# 34000/34000 [==============================] - 4s 106us/step - loss: 0.0189 - val_loss: 0.0273
# Epoch 200/200
# 34000/34000 [==============================] - 3s 95us/step - loss: 0.0179 - val_loss: 0.0236

# %%
model.save_weights('InverseMapNNWeights.h5')

# %%
model.load_weights('InverseMapNNWeights.h5')

# %% [markdown]
# # Check relative errors per parameter

# %%
import matplotlib.ticker as mtick
titles=["$\\xi_0$","$\\nu$","$\\rho$","$H$"]
average=np.zeros(5000)
fig=plt.figure(figsize=(12,8))
for u in range(4):
    ax=plt.subplot(2,2,u+1)
    for i in range(5000):
        y=scale.inverse_transform(y_test_transform[i])[u]
        approx=scale.inverse_transform(model.predict(x_test_transform[i].reshape(1,len(maturities),len(strikes),1)))[0][u]
        plt.plot(y,100*np.abs(approx-y)/np.abs(y),'b*')
        average[i]=np.abs(approx-y)/np.abs(y)
    plt.title(titles[u],fontsize=20)
    plt.ylabel('relative Error',fontsize=15)
    plt.gca().yaxis.set_major_formatter(mtick.PercentFormatter() )
    plt.tick_params(axis='both', which='major', labelsize=15)
    plt.tick_params(axis='both', which='minor', labelsize=15)
    plt.text(0.5, 0.5, 'Average: %1.2f%%'%np.mean(100*average), horizontalalignment='center',verticalalignment='center', transform=ax.transAxes,fontsize=15)

    print("average= ",np.mean(average))
plt.tight_layout()
plt.savefig('InverseMapRelativeErrors.png', dpi=300)
plt.show()
# Out:
# average=  0.005699541785953209
# average=  0.009459068902264767
# average=  0.01531842012210073
# average=  0.012274061548818958
